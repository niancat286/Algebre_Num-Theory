# %% [markdown]
# ### Лабораторна робота №3: Циклічні групи, порядок елемента
#
# **Мета роботи:** Попрацювати з циклічними групами та порядками елементів в Sage

# %% [markdown]
# ---
#
# ### 1. Властивості циклічних груп
#
# Для $n=100,173,530,746,911,1024$ розглянемо циклічну групу $\mathbb{Z}_n$ (або $C_n$):
#
# 1. Для кожного дільника $d$ порядку $n$:<br>
#    1.1 Знайдіть кількість елементів порядку $d$ в групі $\mathbb{Z}_n$ (або $C_n$).<br>
#    1.2 Порівняйте з $\phi(d)$.
# 2. Знайдіть кількість підгруп в групі $\mathbb{Z}_n$ (або $C_n$).<br>
#    Порівняйте з $\tau(n)$.
#
# Проаналізуйте результати та дайте відповіді на запитання:
#
# 1. Скільки елементів порядку $k$ в циклічній групі порядку $n$?
# 2. Cкільки підгруп в циклічній групі порядку $n$?
#
# У циклічній групі порядку n кількість елементів порядку k дорівнює ф\(k\) if k|n або 0 if else. В циклічній групі існує рівно одна підгрупа порядку k для кожного дільника k і в цій підгрупі кількість генераторів = ф\(k\)
#
# Кількість підгруп рівна кількості позитивних дільників n. Кожному дільнику d|n відповідає одна підгрупа порядку d

# %%
ns = [100, 173, 530, 746, 911, 1024]

for n in ns:
    print(f"\n==============================")
    print(f"Циклічна група C_{n} (або Z_{n})")
    print("==============================")
    
    divs = divisors(n)
    print(f"Розклад n = {factor(n)}")
    print(f"Кількість дільників τ(n) = {len(divs)} (це кількість підгруп)\n")
    print(f"{'d (дільник)':>10} | {'φ(d)':>6} | {'# елементів порядку d':>26}")
    print("-"*48)
    total_phi = 0
    for d in divs:
        phi = euler_phi(d)
        total_phi += phi
        print(f"{d:10} | {phi:6} | {phi:26}")
    
    print("-"*48)
    print(f"Σ φ(d) = {total_phi}  → перевірка: Σφ(d) = n ? {'Так' if total_phi==n else 'Ні'}")
    print(f"Отже, кількість підгруп у C_{n} = τ({n}) = {len(divs)}")
# Out:
# ==============================
# Циклічна група C_100 (або Z_100)
# ==============================
# Розклад n = 2^2 * 5^2
# Кількість дільників τ(n) = 9 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#          2 |      1 |                          1
#          4 |      2 |                          2
#          5 |      4 |                          4
#         10 |      4 |                          4
#         20 |      8 |                          8
#         25 |     20 |                         20
#         50 |     20 |                         20
#        100 |     40 |                         40
# ------------------------------------------------
# Σ φ(d) = 100  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_100 = τ(100) = 9
#
# ==============================
# Циклічна група C_173 (або Z_173)
# ==============================
# Розклад n = 173
# Кількість дільників τ(n) = 2 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#        173 |    172 |                        172
# ------------------------------------------------
# Σ φ(d) = 173  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_173 = τ(173) = 2
#
# ==============================
# Циклічна група C_530 (або Z_530)
# ==============================
# Розклад n = 2 * 5 * 53
# Кількість дільників τ(n) = 8 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#          2 |      1 |                          1
#          5 |      4 |                          4
#         10 |      4 |                          4
#         53 |     52 |                         52
#        106 |     52 |                         52
#        265 |    208 |                        208
#        530 |    208 |                        208
# ------------------------------------------------
# Σ φ(d) = 530  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_530 = τ(530) = 8
#
# ==============================
# Циклічна група C_746 (або Z_746)
# ==============================
# Розклад n = 2 * 373
# Кількість дільників τ(n) = 4 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#          2 |      1 |                          1
#        373 |    372 |                        372
#        746 |    372 |                        372
# ------------------------------------------------
# Σ φ(d) = 746  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_746 = τ(746) = 4
#
# ==============================
# Циклічна група C_911 (або Z_911)
# ==============================
# Розклад n = 911
# Кількість дільників τ(n) = 2 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#        911 |    910 |                        910
# ------------------------------------------------
# Σ φ(d) = 911  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_911 = τ(911) = 2
#
# ==============================
# Циклічна група C_1024 (або Z_1024)
# ==============================
# Розклад n = 2^10
# Кількість дільників τ(n) = 11 (це кількість підгруп)
#
# d (дільник) |   φ(d) |      # елементів порядку d
# ------------------------------------------------
#          1 |      1 |                          1
#          2 |      1 |                          1
#          4 |      2 |                          2
#          8 |      4 |                          4
#         16 |      8 |                          8
#         32 |     16 |                         16
#         64 |     32 |                         32
#        128 |     64 |                         64
#        256 |    128 |                        128
#        512 |    256 |                        256
#       1024 |    512 |                        512
# ------------------------------------------------
# Σ φ(d) = 1024  → перевірка: Σφ(d) = n ? Так
# Отже, кількість підгруп у C_1024 = τ(1024) = 11

# %% [markdown]
# ---
#
# ### 2. Порядки елементів в дієдральних групах
#
# Для $n=3,4,...,20$ розглянемо дієдральну групу $D_n$:
#
# 1. Знайдіть кількість елементів порядку $d=2$ в групі $D_n$.
# 2. Для кожного дільника $d>2$ порядку $|D_n|=2n$:<br>
#    Знайдіть кількість елементів порядку $d$ в групі $D_n$.
#
# Проаналізуйте результати та дайте відповіді на запитання:
#
# 1. Скільки елементів порядку $d=2$ в дієдральній групі $D_n$?
# 2. Скільки елементів порядку $d$ в дієдральній групі $D_n$?
# 3. Чи для кожного дільника $d<2n$ порядку групи $D_n$ існує елемент порядку $d$?
#
# Елементів порядку d=2 в Dn = n if n \- непарне, або n\+1 if n \- парне. Стосується відображень, бо вони завжди мають порядок 2. Крім того, якщо n парне, то поворот r\_n/2 має порядок 2 і додає ще один такий елемент.
#
# Якщо d =1, то тільки 1. Якщо d=2 див вище. Якщо d&gt;2 елементи порядку d в Dn можуть бути тільки поворотами. Повороти утворюють циклічну підгрупу &lt;r&gt; iso Cn. Тому таких елементів буде ф\(d\) if d|n, or 0 is d !| n.
#
# Ні, дільники d числа 2n діляться на дві групи:
#
# Якщо d=2 — завжди є \(див. п.1\).
#
# Якщо d&gt;2 і d|n — тоді є \(повороти\), їх кількість = ф\(d\).
#
# Якщо d&gt;2 і d !| n \(тобто d ділить 2n але не ділить n\) — тоді в Dn немає елементів порядку d. \(Відображення мають тільки порядок 2, повороти мають порядки, що ділять n\)

# %%
for n in range(3, 21):
    print(f"\n==============================")
    print(f"Дієдральна група D_{n} (порядок = {2*n})")

    # Дільники порядку групи (2n)
    divs = divisors(2*n)
    print(f"Дільники 2n = {divs}")

    # к-ть ел-тів ord 2:
    count_2 = n + (1 if n % 2 == 0 else 0)

    # таблиця для кожного дільника
    print(" d | кількість елементів порядку d у D_n")
    print("-------------------------------------------")

    for d in divs:
        if d == 1:
            cnt = 1
        elif d == 2:
            cnt = count_2
        elif d > 2 and n % d == 0:
            cnt = euler_phi(d)
        else:
            cnt = 0
        print(f"{d:2d} | {cnt}")
# Out:
# ==============================
# Дієдральна група D_3 (порядок = 6)
# Дільники 2n = [1, 2, 3, 6]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 3
#  3 | 2
#  6 | 0
#
# ==============================
# Дієдральна група D_4 (порядок = 8)
# Дільники 2n = [1, 2, 4, 8]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 5
#  4 | 2
#  8 | 0
#
# ==============================
# Дієдральна група D_5 (порядок = 10)
# Дільники 2n = [1, 2, 5, 10]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 5
#  5 | 4
# 10 | 0
#
# ==============================
# Дієдральна група D_6 (порядок = 12)
# Дільники 2n = [1, 2, 3, 4, 6, 12]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 7
#  3 | 2
#  4 | 0
#  6 | 2
# 12 | 0
#
# ==============================
# Дієдральна група D_7 (порядок = 14)
# Дільники 2n = [1, 2, 7, 14]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 7
#  7 | 6
# 14 | 0
#
# ==============================
# Дієдральна група D_8 (порядок = 16)
# Дільники 2n = [1, 2, 4, 8, 16]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 9
#  4 | 2
#  8 | 4
# 16 | 0
#
# ==============================
# Дієдральна група D_9 (порядок = 18)
# Дільники 2n = [1, 2, 3, 6, 9, 18]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 9
#  3 | 2
#  6 | 0
#  9 | 6
# 18 | 0
#
# ==============================
# Дієдральна група D_10 (порядок = 20)
# Дільники 2n = [1, 2, 4, 5, 10, 20]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 11
#  4 | 0
#  5 | 4
# 10 | 4
# 20 | 0
#
# ==============================
# Дієдральна група D_11 (порядок = 22)
# Дільники 2n = [1, 2, 11, 22]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 11
# 11 | 10
# 22 | 0
#
# ==============================
# Дієдральна група D_12 (порядок = 24)
# Дільники 2n = [1, 2, 3, 4, 6, 8, 12, 24]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 13
#  3 | 2
#  4 | 2
#  6 | 2
#  8 | 0
# 12 | 4
# 24 | 0
#
# ==============================
# Дієдральна група D_13 (порядок = 26)
# Дільники 2n = [1, 2, 13, 26]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 13
# 13 | 12
# 26 | 0
#
# ==============================
# Дієдральна група D_14 (порядок = 28)
# Дільники 2n = [1, 2, 4, 7, 14, 28]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 15
#  4 | 0
#  7 | 6
# 14 | 6
# 28 | 0
#
# ==============================
# Дієдральна група D_15 (порядок = 30)
# Дільники 2n = [1, 2, 3, 5, 6, 10, 15, 30]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 15
#  3 | 2
#  5 | 4
#  6 | 0
# 10 | 0
# 15 | 8
# 30 | 0
#
# ==============================
# Дієдральна група D_16 (порядок = 32)
# Дільники 2n = [1, 2, 4, 8, 16, 32]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 17
#  4 | 2
#  8 | 4
# 16 | 8
# 32 | 0
#
# ==============================
# Дієдральна група D_17 (порядок = 34)
# Дільники 2n = [1, 2, 17, 34]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 17
# 17 | 16
# 34 | 0
#
# ==============================
# Дієдральна група D_18 (порядок = 36)
# Дільники 2n = [1, 2, 3, 4, 6, 9, 12, 18, 36]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 19
#  3 | 2
#  4 | 0
#  6 | 2
#  9 | 6
# 12 | 0
# 18 | 6
# 36 | 0
#
# ==============================
# Дієдральна група D_19 (порядок = 38)
# Дільники 2n = [1, 2, 19, 38]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 19
# 19 | 18
# 38 | 0
#
# ==============================
# Дієдральна група D_20 (порядок = 40)
# Дільники 2n = [1, 2, 4, 5, 8, 10, 20, 40]
#  d | кількість елементів порядку d у D_n
# -------------------------------------------
#  1 | 1
#  2 | 21
#  4 | 2
#  5 | 4
#  8 | 0
# 10 | 4
# 20 | 8
# 40 | 0

# %% [markdown]
# ---
#
# ### 3. Дискретний логарифм в групі $\mathbb{Z}_n^{*}$
#
# Розглянемо групу $\mathbb{Z}_n^{*}$ для $n=1102158078129785185997827239806$.
#
# 1. Перевірте, що група є циклічною і знайдіть її порядок.
# 2. Знайдіть найменше натуральне $a\in\mathbb{N}$ таке, що елемент $\overline{a}\in\mathbb{Z}_n^{*}$ є твірним групи.
# 3. Перевірте, що порядок елемента $\overline{a}$ дорівнює $\phi(n)$.
# 4. Виберіть три випадкових елементи $g_1,g_2,g_3$ групи $\mathbb{Z}_n^{*}$.
# 5. Для кожного $g$ знайдіть степінь $k$ такий, що $g=\overline{a}^k$.

# %%
n = 1102158078129785185997827239806
G = Integers(n)

# Група Z_n* є циклічною, якщо n = 2, 4, p^k, або 2*p^k, де p - непарне просте
n_factors = factor(n)
# (Z/2pZ)^* циклічна, якщо p — непарне просте.
is_cyclic = (p % 2 == 1)
print("Група Z*_n циклічна?", is_cyclic)

if not is_cyclic:
    print("Група не циклічна, далі не перевіряєм")
else:
    phi_n = euler_phi(n)
    print(f"Порядок групи G функція Ойлера = {phi_n}")
    
    ord_fact = factor(phi_n)
    prime_div = [p for p, exp in ord_fact]
    print(f"Прості дільники порядку: {prime_div}")

    a_val = None
    for a_cand in range(2, 100): 
        a = G(a_cand) 
        if gcd(a, n) != 1:
            continue
            
        is_generator_flag = True
        for q in prime_div:
            if power_mod(a, phi_n // q, n) == 1:
                is_generator_flag = False
                break
        
        if is_generator_flag:
            a_val = a
            print(f"\найменший твірний елемент: a = {a_val}")
            break

    if a_val is not None:
        order_of_a = a_val.multiplicative_order()
        print(f"Порядок елемента a: {order_of_a}")
        print(f"Порядок збігається з ф(n)? {order_of_a == phi_n}")

        
        print("\nЗнаходження k для рандомних g = a^k:")
        for i in range(3):
            k_rand = ZZ.random_element(1, phi_n)
            g = power_mod(a_val, k_rand, n)
            g_elem = G(g)
            k_found = discrete_log(g_elem, a_val)            
                
            print(f"g = {g}")
            print(f" степінь k = {k_found}")
# Out:
# Група Z*_n циклічна? True
# Порядок групи G функція Ойлера = 551079039064892592998913619902
# Прості дільники порядку: [2, 3, 419, 1354307, 2673109177, 60550090837]
# \найменший твірний елемент: a = 3
# Порядок елемента a: 551079039064892592998913619902
# Порядок збігається з ф(n)? True
#
# Знаходження k для рандомних g = a^k:
# g = 226372485055078781719748845905
#  степінь k = 456137700736916355374765729945
# g = 53329358686869235055302550997
#  степінь k = 498921872398205792311287168173
# g = 255008585686322558391072295999
#  степінь k = 289794914246406538906205176042

# %% [markdown]
# ---
#
# ### 4. Одна група матриць
#
# Розглянемо підгрупу $G$ групи $GL_2(\mathbb{Z})$, породжену двома матрицями:
#
# $$G = \left\langle \left(\begin{array}{rrr}
# 1 & 0 & 1 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{array}\right),  \left(\begin{array}{rrr}
# 1 & 0 & 0 \\
# 0 & 1 & 1 \\
# 0 & 0 & 1
# \end{array}\right)\right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. Чи є група G скінченною?
# 2. Чи є група G абелевою?
# 3. Які порядки мають елементи групи G?
# 4. Який вигляд мають елементи групи G?
# 5. Чи є група $G$ циклічною?
# 6. Якій групі ізоморфна група G?
#
# __Відповіді__:
#
# 1. ... ні
# 2. ... так
# 3. ... нескінченні
# 4. ... \[\[1, 0, x\], \[0, 1, y\], \[0, 0, 1\]\], де x, y є Z
# 5. ... ні
# 6. ... Z x Z

# %%
# Завдання 4. Підгрупа G групи GL_2(Z), породжена двома матрицями

A = matrix([[1,0,1],
            [0,1,0],
            [0,0,1]])

B = matrix([[1,0,0],
            [0,1,1],
            [0,0,1]])

G = MatrixGroup([A, B])
print("Група G породжена двома матрицями A та B:")

print("A ="); show(A)
print("B ="); show(B)

# 1) Чи група скінченна?
print("\n1) Група G скінченна?", G.is_finite())

# 2) Чи G абелева?
print("2) Чи G абелева?", G.is_abelian())

# 3) Порядки елементів групи
print("\n3) Порядки елементів групи G:")
for g in G.gens():
    print(g, "→ порядок =", g.order())

# 4) Який вигляд мають елементи групи?
print("\n4) Елементи групи G:")
print("Елементи групи мають вигляд:")
print("[[1, 0, x],")
print(" [0, 1, y],") 
print(" [0, 0, 1]]")
print("де x, y є Z")

def group_element(x, y):
    return matrix(ZZ, [[1, 0, x],
                      [0, 1, y],
                      [0, 0, 1]])

M1 = group_element(2, 3)
M2 = group_element(1, -1)
print(f"\nПриклад множення:")
print(f"M1 = {M1.list()}")
print(f"M2 = {M2.list()}")
print(f"M1 * M2 = {(M1 * M2).list()}")
print(f"M2 * M1 = {(M2 * M1).list()}")

# 5) Чи G циклічна?
print("\n5) Чи група G циклічна?")
print("оскільки A породжує підгрупу: A^n = [[1, 0, n], [0, 1, 0], [0, 0, 1]], а B породжує підгрупу: B^n = [[1, 0, 0], [0, 1, n], [0, 0, 1]]")
print("група циклічна, то один з генераторів повинен породжувати всю групу, але жоден з наших не породжує. Отже НЕ циклічна")

# 6) До якої групи ізоморфна G
print("\n6) Група G ізоморфна:")
print("Відображення ф: G → Z x Z")
print("ф([[1, 0, x], [0, 1, y], [0, 0, 1]]) = (x, y)")
# Out:
# Група G породжена двома матрицями A та B:
# A =
# [1 0 1]
# [0 1 0]
# [0 0 1]
# B =
# [1 0 0]
# [0 1 1]
# [0 0 1]
# 1) Група G скінченна? False
# 2) Чи G абелева? True
#
# 3) Порядки елементів групи G:
# [1 0 1]
# [0 1 0]
# [0 0 1] → порядок = +Infinity
# [1 0 0]
# [0 1 1]
# [0 0 1] → порядок = +Infinity
#
# 4) Елементи групи G:
# Елементи групи мають вигляд:
# [[1, 0, x],
#  [0, 1, y],
#  [0, 0, 1]]
# де x, y є Z
#
# Приклад множення:
# M1 = [1, 0, 2, 0, 1, 3, 0, 0, 1]
# M2 = [1, 0, 1, 0, 1, -1, 0, 0, 1]
# M1 * M2 = [1, 0, 3, 0, 1, 2, 0, 0, 1]
# M2 * M1 = [1, 0, 3, 0, 1, 2, 0, 0, 1]
#
# 5) Чи група G циклічна?
# оскільки A породжує підгрупу: A^n = [[1, 0, n], [0, 1, 0], [0, 0, 1]], а B породжує підгрупу: B^n = [[1, 0, 0], [0, 1, n], [0, 0, 1]]
# група циклічна, то один з генераторів повинен породжувати всю групу, але жоден з наших не породжує. Отже НЕ циклічна
#
# 6) Група G ізоморфна:
# Відображення ф: G → Z x Z
# ф([[1, 0, x], [0, 1, y], [0, 0, 1]]) = (x, y)

# %% [markdown]
# ---
#
# ### 5\*. Групи $\mathbb{Z}_n^{*}$
#
# 1. Для кожного $n=2,3,4,\ldots,1000$ надрукуйте: <br>
#        1.1. Розклад $n$ у добуток простих.<br>
#        1.2. Відповідь, чи є група $\mathbb{Z}_n^{*}$ циклічною.<br>
#        1.3. Якщо $\mathbb{Z}_n^{*}$ є циклічною, то знайти найменше $a\in\mathbb{N}$ таке, що $\overline{a}$ є твірним групи.
# 3. Сформулюйте гіпотезу про те, для яких $n\in\mathbb{N}$ група $\mathbb{Z}_n^{*}$ є циклічною.
#
# **Ваша гіпотеза**:  є циклічними саме ті і лише ті модулі, які рівні 1, 2, 4 або ступеням непарного простого, або подвоєним ступеням непарного простого.

# %%
def smallest_generator(n):
    # phi(n)
    phi = euler_phi(n)

    # прості дільники phi
    F = factor(phi)
    prime_divs = [int(p[0]) for p in F]  # беремо лише прості

    # перебір g
    for g in range(2, n):
        if gcd(g, n) != 1:
            continue  # якщо не взаємно просте з n -> не елемент групи

        # перевірка степенів
        good = True
        for q in prime_divs:
            if power_mod(g, phi//q, n) == 1:
                good = False
                break

        if good:
            return g  # перший коректний — найменший

    return None  # якщо група не циклічна


for i in range(2, 1001):
    print(f"factor {i}=", factor(i))
    G = Zmod(i).unit_group()
    cycl = G.is_cyclic()
    print(f"Z*{i} is cyclic", cycl)
    if cycl:
        print(f"smallest generator for Z*{i}= " , smallest_generator(i))
    print()
# Out:
# factor 2= 2
# Z*2 is cyclic True
# smallest generator for Z*2=  None
#
# factor 3= 3
# Z*3 is cyclic True
# smallest generator for Z*3=  2
#
# factor 4= 2^2
# Z*4 is cyclic True
# smallest generator for Z*4=  3
#
# factor 5= 5
# Z*5 is cyclic True
# smallest generator for Z*5=  2
#
# factor 6= 2 * 3
# Z*6 is cyclic True
# smallest generator for Z*6=  5
#
# factor 7= 7
# Z*7 is cyclic True
# smallest generator for Z*7=  3
#
# factor 8= 2^3
# Z*8 is cyclic False
#
# factor 9= 3^2
# Z*9 is cyclic True
# smallest generator for Z*9=  2
#
# factor 10= 2 * 5
# Z*10 is cyclic True
# smallest generator for Z*10=  3
#
# factor 11= 11
# Z*11 is cyclic True
# smallest generator for Z*11=  2
#
# factor 12= 2^2 * 3
# Z*12 is cyclic False
#
# factor 13= 13
# Z*13 is cyclic True
# smallest generator for Z*13=  2
#
# factor 14= 2 * 7
# Z*14 is cyclic True
# smallest generator for Z*14=  3
#
# factor 15= 3 * 5
# Z*15 is cyclic False
#
# factor 16= 2^4
# Z*16 is cyclic False
#
# factor 17= 17
# Z*17 is cyclic True
# smallest generator for Z*17=  3
#
# factor 18= 2 * 3^2
# Z*18 is cyclic True
# smallest generator for Z*18=  5
#
# factor 19= 19
# Z*19 is cyclic True
# smallest generator for Z*19=  2
#
# factor 20= 2^2 * 5
# Z*20 is cyclic False
#
# factor 21= 3 * 7
# Z*21 is cyclic False
#
# factor 22= 2 * 11
# Z*22 is cyclic True
# smallest generator for Z*22=  7
#
# factor 23= 23
# Z*23 is cyclic True
# smallest generator for Z*23=  5
#
# factor 24= 2^3 * 3
# Z*24 is cyclic False
#
# factor 25= 5^2
# Z*25 is cyclic True
# smallest generator for Z*25=  2
#
# factor 26= 2 * 13
# Z*26 is cyclic True
# smallest generator for Z*26=  7
#
# factor 27= 3^3
# Z*27 is cyclic True
# smallest generator for Z*27=  2
#
# factor 28= 2^2 * 7
# Z*28 is cyclic False
#
# factor 29= 29
# Z*29 is cyclic True
# smallest generator for Z*29=  2
#
# factor 30= 2 * 3 * 5
# Z*30 is cyclic False
#
# factor 31= 31
# Z*31 is cyclic True
# smallest generator for Z*31=  3
#
# factor 32= 2^5
# Z*32 is cyclic False
#
# factor 33= 3 * 11
# Z*33 is cyclic False
#
# factor 34= 2 * 17
# Z*34 is cyclic True
# smallest generator for Z*34=  3
#
# factor 35= 5 * 7
# Z*35 is cyclic False
#
# factor 36= 2^2 * 3^2
# Z*36 is cyclic False
#
# factor 37= 37
# Z*37 is cyclic True
# smallest generator for Z*37=  2
#
# factor 38= 2 * 19
# Z*38 is cyclic True
# smallest generator for Z*38=  3
#
# factor 39= 3 * 13
# Z*39 is cyclic False
#
# factor 40= 2^3 * 5
# Z*40 is cyclic False
#
# factor 41= 41
# Z*41 is cyclic True
# smallest generator for Z*41=  6
#
# factor 42= 2 * 3 * 7
# Z*42 is cyclic False
#
# factor 43= 43
# Z*43 is cyclic True
# smallest generator for Z*43=  3
#
# factor 44= 2^2 * 11
# Z*44 is cyclic False
#
# factor 45= 3^2 * 5
# Z*45 is cyclic False
#
# factor 46= 2 * 23
# Z*46 is cyclic True
# smallest generator for Z*46=  5
#
# factor 47= 47
# Z*47 is cyclic True
# smallest generator for Z*47=  5
#
# factor 48= 2^4 * 3
# Z*48 is cyclic False
#
# factor 49= 7^2
# Z*49 is cyclic True
# smallest generator for Z*49=  3
#
# factor 50= 2 * 5^2
# Z*50 is cyclic True
# smallest generator for Z*50=  3
#
# factor 51= 3 * 17
# Z*51 is cyclic False
#
# factor 52= 2^2 * 13
# Z*52 is cyclic False
#
# factor 53= 53
# Z*53 is cyclic True
# smallest generator for Z*53=  2
#
# factor 54= 2 * 3^3
# Z*54 is cyclic True
# smallest generator for Z*54=  5
#
# factor 55= 5 * 11
# Z*55 is cyclic False
#
# factor 56= 2^3 * 7
# Z*56 is cyclic False
#
# factor 57= 3 * 19
# Z*57 is cyclic False
#
# factor 58= 2 * 29
# Z*58 is cyclic True
# smallest generator for Z*58=  3
#
# factor 59= 59
# Z*59 is cyclic True
# smallest generator for Z*59=  2
#
# factor 60= 2^2 * 3 * 5
# Z*60 is cyclic False
#
# factor 61= 61
# Z*61 is cyclic True
# smallest generator for Z*61=  2
#
# factor 62= 2 * 31
# Z*62 is cyclic True
# smallest generator for Z*62=  3
#
# factor 63= 3^2 * 7
# Z*63 is cyclic False
#
# factor 64= 2^6
# Z*64 is cyclic False
#
# factor 65= 5 * 13
# Z*65 is cyclic False
#
# factor 66= 2 * 3 * 11
# Z*66 is cyclic False
#
# factor 67= 67
# Z*67 is cyclic True
# smallest generator for Z*67=  2
#
# factor 68= 2^2 * 17
# Z*68 is cyclic False
#
# factor 69= 3 * 23
# Z*69 is cyclic False
#
# factor 70= 2 * 5 * 7
# Z*70 is cyclic False
#
# factor 71= 71
# Z*71 is cyclic True
# smallest generator for Z*71=  7
#
# factor 72= 2^3 * 3^2
# Z*72 is cyclic False
#
# factor 73= 73
# Z*73 is cyclic True
# smallest generator for Z*73=  5
#
# factor 74= 2 * 37
# Z*74 is cyclic True
# smallest generator for Z*74=  5
#
# factor 75= 3 * 5^2
# Z*75 is cyclic False
#
# factor 76= 2^2 * 19
# Z*76 is cyclic False
#
# factor 77= 7 * 11
# Z*77 is cyclic False
#
# factor 78= 2 * 3 * 13
# Z*78 is cyclic False
#
# factor 79= 79
# Z*79 is cyclic True
# smallest generator for Z*79=  3
#
# factor 80= 2^4 * 5
# Z*80 is cyclic False
#
# factor 81= 3^4
# Z*81 is cyclic True
# smallest generator for Z*81=  2
#
# factor 82= 2 * 41
# Z*82 is cyclic True
# smallest generator for Z*82=  7
#
# factor 83= 83
# Z*83 is cyclic True
# smallest generator for Z*83=  2
#
# factor 84= 2^2 * 3 * 7
# Z*84 is cyclic False
#
# factor 85= 5 * 17
# Z*85 is cyclic False
#
# factor 86= 2 * 43
# Z*86 is cyclic True
# smallest generator for Z*86=  3
#
# factor 87= 3 * 29
# Z*87 is cyclic False
#
# factor 88= 2^3 * 11
# Z*88 is cyclic False
#
# factor 89= 89
# Z*89 is cyclic True
# smallest generator for Z*89=  3
#
# factor 90= 2 * 3^2 * 5
# Z*90 is cyclic False
#
# factor 91= 7 * 13
# Z*91 is cyclic False
#
# factor 92= 2^2 * 23
# Z*92 is cyclic False
#
# factor 93= 3 * 31
# Z*93 is cyclic False
#
# factor 94= 2 * 47
# Z*94 is cyclic True
# smallest generator for Z*94=  5
#
# factor 95= 5 * 19
# Z*95 is cyclic False
#
# factor 96= 2^5 * 3
# Z*96 is cyclic False
#
# factor 97= 97
# Z*97 is cyclic True
# smallest generator for Z*97=  5
#
# factor 98= 2 * 7^2
# Z*98 is cyclic True
# smallest generator for Z*98=  3
#
# factor 99= 3^2 * 11
# Z*99 is cyclic False
#
# factor 100= 2^2 * 5^2
# Z*100 is cyclic False
#
# factor 101= 101
# Z*101 is cyclic True
# smallest generator for Z*101=  2
#
# factor 102= 2 * 3 * 17
# Z*102 is cyclic False
#
# factor 103= 103
# Z*103 is cyclic True
# smallest generator for Z*103=  5
#
# factor 104= 2^3 * 13
# Z*104 is cyclic False
#
# factor 105= 3 * 5 * 7
# Z*105 is cyclic False
#
# factor 106= 2 * 53
# Z*106 is cyclic True
# smallest generator for Z*106=  3
#
# factor 107= 107
# Z*107 is cyclic True
# smallest generator for Z*107=  2
#
# factor 108= 2^2 * 3^3
# Z*108 is cyclic False
#
# factor 109= 109
# Z*109 is cyclic True
# smallest generator for Z*109=  6
#
# factor 110= 2 * 5 * 11
# Z*110 is cyclic False
#
# factor 111= 3 * 37
# Z*111 is cyclic False
#
# factor 112= 2^4 * 7
# Z*112 is cyclic False
#
# factor 113= 113
# Z*113 is cyclic True
# smallest generator for Z*113=  3
#
# factor 114= 2 * 3 * 19
# Z*114 is cyclic False
#
# factor 115= 5 * 23
# Z*115 is cyclic False
#
# factor 116= 2^2 * 29
# Z*116 is cyclic False
#
# factor 117= 3^2 * 13
# Z*117 is cyclic False
#
# factor 118= 2 * 59
# Z*118 is cyclic True
# smallest generator for Z*118=  11
#
# factor 119= 7 * 17
# Z*119 is cyclic False
#
# factor 120= 2^3 * 3 * 5
# Z*120 is cyclic False
#
# factor 121= 11^2
# Z*121 is cyclic True
# smallest generator for Z*121=  2
#
# factor 122= 2 * 61
# Z*122 is cyclic True
# smallest generator for Z*122=  7
#
# factor 123= 3 * 41
# Z*123 is cyclic False
#
# factor 124= 2^2 * 31
# Z*124 is cyclic False
#
# factor 125= 5^3
# Z*125 is cyclic True
# smallest generator for Z*125=  2
#
# factor 126= 2 * 3^2 * 7
# Z*126 is cyclic False
#
# factor 127= 127
# Z*127 is cyclic True
# smallest generator for Z*127=  3
#
# factor 128= 2^7
# Z*128 is cyclic False
#
# factor 129= 3 * 43
# Z*129 is cyclic False
#
# factor 130= 2 * 5 * 13
# Z*130 is cyclic False
#
# factor 131= 131
# Z*131 is cyclic True
# smallest generator for Z*131=  2
#
# factor 132= 2^2 * 3 * 11
# Z*132 is cyclic False
#
# factor 133= 7 * 19
# Z*133 is cyclic False
#
# factor 134= 2 * 67
# Z*134 is cyclic True
# smallest generator for Z*134=  7
#
# factor 135= 3^3 * 5
# Z*135 is cyclic False
#
# factor 136= 2^3 * 17
# Z*136 is cyclic False
#
# factor 137= 137
# Z*137 is cyclic True
# smallest generator for Z*137=  3
#
# factor 138= 2 * 3 * 23
# Z*138 is cyclic False
#
# factor 139= 139
# Z*139 is cyclic True
# smallest generator for Z*139=  2
#
# factor 140= 2^2 * 5 * 7
# Z*140 is cyclic False
#
# factor 141= 3 * 47
# Z*141 is cyclic False
#
# factor 142= 2 * 71
# Z*142 is cyclic True
# smallest generator for Z*142=  7
#
# factor 143= 11 * 13
# Z*143 is cyclic False
#
# factor 144= 2^4 * 3^2
# Z*144 is cyclic False
#
# factor 145= 5 * 29
# Z*145 is cyclic False
#
# factor 146= 2 * 73
# Z*146 is cyclic True
# smallest generator for Z*146=  5
#
# factor 147= 3 * 7^2
# Z*147 is cyclic False
#
# factor 148= 2^2 * 37
# Z*148 is cyclic False
#
# factor 149= 149
# Z*149 is cyclic True
# smallest generator for Z*149=  2
#
# factor 150= 2 * 3 * 5^2
# Z*150 is cyclic False
#
# factor 151= 151
# Z*151 is cyclic True
# smallest generator for Z*151=  6
#
# factor 152= 2^3 * 19
# Z*152 is cyclic False
#
# factor 153= 3^2 * 17
# Z*153 is cyclic False
#
# factor 154= 2 * 7 * 11
# Z*154 is cyclic False
#
# factor 155= 5 * 31
# Z*155 is cyclic False
#
# factor 156= 2^2 * 3 * 13
# Z*156 is cyclic False
#
# factor 157= 157
# Z*157 is cyclic True
# smallest generator for Z*157=  5
#
# factor 158= 2 * 79
# Z*158 is cyclic True
# smallest generator for Z*158=  3
#
# factor 159= 3 * 53
# Z*159 is cyclic False
#
# factor 160= 2^5 * 5
# Z*160 is cyclic False
#
# factor 161= 7 * 23
# Z*161 is cyclic False
#
# factor 162= 2 * 3^4
# Z*162 is cyclic True
# smallest generator for Z*162=  5
#
# factor 163= 163
# Z*163 is cyclic True
# smallest generator for Z*163=  2
#
# factor 164= 2^2 * 41
# Z*164 is cyclic False
#
# factor 165= 3 * 5 * 11
# Z*165 is cyclic False
#
# factor 166= 2 * 83
# Z*166 is cyclic True
# smallest generator for Z*166=  5
#
# factor 167= 167
# Z*167 is cyclic True
# smallest generator for Z*167=  5
#
# factor 168= 2^3 * 3 * 7
# Z*168 is cyclic False
#
# factor 169= 13^2
# Z*169 is cyclic True
# smallest generator for Z*169=  2
#
# factor 170= 2 * 5 * 17
# Z*170 is cyclic False
#
# factor 171= 3^2 * 19
# Z*171 is cyclic False
#
# factor 172= 2^2 * 43
# Z*172 is cyclic False
#
# factor 173= 173
# Z*173 is cyclic True
# smallest generator for Z*173=  2
#
# factor 174= 2 * 3 * 29
# Z*174 is cyclic False
#
# factor 175= 5^2 * 7
# Z*175 is cyclic False
#
# factor 176= 2^4 * 11
# Z*176 is cyclic False
#
# factor 177= 3 * 59
# Z*177 is cyclic False
#
# factor 178= 2 * 89
# Z*178 is cyclic True
# smallest generator for Z*178=  3
#
# factor 179= 179
# Z*179 is cyclic True
# smallest generator for Z*179=  2
#
# factor 180= 2^2 * 3^2 * 5
# Z*180 is cyclic False
#
# factor 181= 181
# Z*181 is cyclic True
# smallest generator for Z*181=  2
#
# factor 182= 2 * 7 * 13
# Z*182 is cyclic False
#
# factor 183= 3 * 61
# Z*183 is cyclic False
#
# factor 184= 2^3 * 23
# Z*184 is cyclic False
#
# factor 185= 5 * 37
# Z*185 is cyclic False
#
# factor 186= 2 * 3 * 31
# Z*186 is cyclic False
#
# factor 187= 11 * 17
# Z*187 is cyclic False
#
# factor 188= 2^2 * 47
# Z*188 is cyclic False
#
# factor 189= 3^3 * 7
# Z*189 is cyclic False
#
# factor 190= 2 * 5 * 19
# Z*190 is cyclic False
#
# factor 191= 191
# Z*191 is cyclic True
# smallest generator for Z*191=  19
#
# factor 192= 2^6 * 3
# Z*192 is cyclic False
#
# factor 193= 193
# Z*193 is cyclic True
# smallest generator for Z*193=  5
#
# factor 194= 2 * 97
# Z*194 is cyclic True
# smallest generator for Z*194=  5
#
# factor 195= 3 * 5 * 13
# Z*195 is cyclic False
#
# factor 196= 2^2 * 7^2
# Z*196 is cyclic False
#
# factor 197= 197
# Z*197 is cyclic True
# smallest generator for Z*197=  2
#
# factor 198= 2 * 3^2 * 11
# Z*198 is cyclic False
#
# factor 199= 199
# Z*199 is cyclic True
# smallest generator for Z*199=  3
#
# factor 200= 2^3 * 5^2
# Z*200 is cyclic False
#
# factor 201= 3 * 67
# Z*201 is cyclic False
#
# factor 202= 2 * 101
# Z*202 is cyclic True
# smallest generator for Z*202=  3
#
# factor 203= 7 * 29
# Z*203 is cyclic False
#
# factor 204= 2^2 * 3 * 17
# Z*204 is cyclic False
#
# factor 205= 5 * 41
# Z*205 is cyclic False
#
# factor 206= 2 * 103
# Z*206 is cyclic True
# smallest generator for Z*206=  5
#
# factor 207= 3^2 * 23
# Z*207 is cyclic False
#
# factor 208= 2^4 * 13
# Z*208 is cyclic False
#
# factor 209= 11 * 19
# Z*209 is cyclic False
#
# factor 210= 2 * 3 * 5 * 7
# Z*210 is cyclic False
#
# factor 211= 211
# Z*211 is cyclic True
# smallest generator for Z*211=  2
#
# factor 212= 2^2 * 53
# Z*212 is cyclic False
#
# factor 213= 3 * 71
# Z*213 is cyclic False
#
# factor 214= 2 * 107
# Z*214 is cyclic True
# smallest generator for Z*214=  5
#
# factor 215= 5 * 43
# Z*215 is cyclic False
#
# factor 216= 2^3 * 3^3
# Z*216 is cyclic False
#
# factor 217= 7 * 31
# Z*217 is cyclic False
#
# factor 218= 2 * 109
# Z*218 is cyclic True
# smallest generator for Z*218=  11
#
# factor 219= 3 * 73
# Z*219 is cyclic False
#
# factor 220= 2^2 * 5 * 11
# Z*220 is cyclic False
#
# factor 221= 13 * 17
# Z*221 is cyclic False
#
# factor 222= 2 * 3 * 37
# Z*222 is cyclic False
#
# factor 223= 223
# Z*223 is cyclic True
# smallest generator for Z*223=  3
#
# factor 224= 2^5 * 7
# Z*224 is cyclic False
#
# factor 225= 3^2 * 5^2
# Z*225 is cyclic False
#
# factor 226= 2 * 113
# Z*226 is cyclic True
# smallest generator for Z*226=  3
#
# factor 227= 227
# Z*227 is cyclic True
# smallest generator for Z*227=  2
#
# factor 228= 2^2 * 3 * 19
# Z*228 is cyclic False
#
# factor 229= 229
# Z*229 is cyclic True
# smallest generator for Z*229=  6
#
# factor 230= 2 * 5 * 23
# Z*230 is cyclic False
#
# factor 231= 3 * 7 * 11
# Z*231 is cyclic False
#
# factor 232= 2^3 * 29
# Z*232 is cyclic False
#
# factor 233= 233
# Z*233 is cyclic True
# smallest generator for Z*233=  3
#
# factor 234= 2 * 3^2 * 13
# Z*234 is cyclic False
#
# factor 235= 5 * 47
# Z*235 is cyclic False
#
# factor 236= 2^2 * 59
# Z*236 is cyclic False
#
# factor 237= 3 * 79
# Z*237 is cyclic False
#
# factor 238= 2 * 7 * 17
# Z*238 is cyclic False
#
# factor 239= 239
# Z*239 is cyclic True
# smallest generator for Z*239=  7
#
# factor 240= 2^4 * 3 * 5
# Z*240 is cyclic False
#
# factor 241= 241
# Z*241 is cyclic True
# smallest generator for Z*241=  7
#
# factor 242= 2 * 11^2
# Z*242 is cyclic True
# smallest generator for Z*242=  7
#
# factor 243= 3^5
# Z*243 is cyclic True
# smallest generator for Z*243=  2
#
# factor 244= 2^2 * 61
# Z*244 is cyclic False
#
# factor 245= 5 * 7^2
# Z*245 is cyclic False
#
# factor 246= 2 * 3 * 41
# Z*246 is cyclic False
#
# factor 247= 13 * 19
# Z*247 is cyclic False
#
# factor 248= 2^3 * 31
# Z*248 is cyclic False
#
# factor 249= 3 * 83
# Z*249 is cyclic False
#
# factor 250= 2 * 5^3
# Z*250 is cyclic True
# smallest generator for Z*250=  3
#
# factor 251= 251
# Z*251 is cyclic True
# smallest generator for Z*251=  6
#
# factor 252= 2^2 * 3^2 * 7
# Z*252 is cyclic False
#
# factor 253= 11 * 23
# Z*253 is cyclic False
#
# factor 254= 2 * 127
# Z*254 is cyclic True
# smallest generator for Z*254=  3
#
# factor 255= 3 * 5 * 17
# Z*255 is cyclic False
#
# factor 256= 2^8
# Z*256 is cyclic False
#
# factor 257= 257
# Z*257 is cyclic True
# smallest generator for Z*257=  3
#
# factor 258= 2 * 3 * 43
# Z*258 is cyclic False
#
# factor 259= 7 * 37
# Z*259 is cyclic False
#
# factor 260= 2^2 * 5 * 13
# Z*260 is cyclic False
#
# factor 261= 3^2 * 29
# Z*261 is cyclic False
#
# factor 262= 2 * 131
# Z*262 is cyclic True
# smallest generator for Z*262=  17
#
# factor 263= 263
# Z*263 is cyclic True
# smallest generator for Z*263=  5
#
# factor 264= 2^3 * 3 * 11
# Z*264 is cyclic False
#
# factor 265= 5 * 53
# Z*265 is cyclic False
#
# factor 266= 2 * 7 * 19
# Z*266 is cyclic False
#
# factor 267= 3 * 89
# Z*267 is cyclic False
#
# factor 268= 2^2 * 67
# Z*268 is cyclic False
#
# factor 269= 269
# Z*269 is cyclic True
# smallest generator for Z*269=  2
#
# factor 270= 2 * 3^3 * 5
# Z*270 is cyclic False
#
# factor 271= 271
# Z*271 is cyclic True
# smallest generator for Z*271=  6
#
# factor 272= 2^4 * 17
# Z*272 is cyclic False
#
# factor 273= 3 * 7 * 13
# Z*273 is cyclic False
#
# factor 274= 2 * 137
# Z*274 is cyclic True
# smallest generator for Z*274=  3
#
# factor 275= 5^2 * 11
# Z*275 is cyclic False
#
# factor 276= 2^2 * 3 * 23
# Z*276 is cyclic False
#
# factor 277= 277
# Z*277 is cyclic True
# smallest generator for Z*277=  5
#
# factor 278= 2 * 139
# Z*278 is cyclic True
# smallest generator for Z*278=  3
#
# factor 279= 3^2 * 31
# Z*279 is cyclic False
#
# factor 280= 2^3 * 5 * 7
# Z*280 is cyclic False
#
# factor 281= 281
# Z*281 is cyclic True
# smallest generator for Z*281=  3
#
# factor 282= 2 * 3 * 47
# Z*282 is cyclic False
#
# factor 283= 283
# Z*283 is cyclic True
# smallest generator for Z*283=  3
#
# factor 284= 2^2 * 71
# Z*284 is cyclic False
#
# factor 285= 3 * 5 * 19
# Z*285 is cyclic False
#
# factor 286= 2 * 11 * 13
# Z*286 is cyclic False
#
# factor 287= 7 * 41
# Z*287 is cyclic False
#
# factor 288= 2^5 * 3^2
# Z*288 is cyclic False
#
# factor 289= 17^2
# Z*289 is cyclic True
# smallest generator for Z*289=  3
#
# factor 290= 2 * 5 * 29
# Z*290 is cyclic False
#
# factor 291= 3 * 97
# Z*291 is cyclic False
#
# factor 292= 2^2 * 73
# Z*292 is cyclic False
#
# factor 293= 293
# Z*293 is cyclic True
# smallest generator for Z*293=  2
#
# factor 294= 2 * 3 * 7^2
# Z*294 is cyclic False
#
# factor 295= 5 * 59
# Z*295 is cyclic False
#
# factor 296= 2^3 * 37
# Z*296 is cyclic False
#
# factor 297= 3^3 * 11
# Z*297 is cyclic False
#
# factor 298= 2 * 149
# Z*298 is cyclic True
# smallest generator for Z*298=  3
#
# factor 299= 13 * 23
# Z*299 is cyclic False
#
# factor 300= 2^2 * 3 * 5^2
# Z*300 is cyclic False
#
# factor 301= 7 * 43
# Z*301 is cyclic False
#
# factor 302= 2 * 151
# Z*302 is cyclic True
# smallest generator for Z*302=  7
#
# factor 303= 3 * 101
# Z*303 is cyclic False
#
# factor 304= 2^4 * 19
# Z*304 is cyclic False
#
# factor 305= 5 * 61
# Z*305 is cyclic False
#
# factor 306= 2 * 3^2 * 17
# Z*306 is cyclic False
#
# factor 307= 307
# Z*307 is cyclic True
# smallest generator for Z*307=  5
#
# factor 308= 2^2 * 7 * 11
# Z*308 is cyclic False
#
# factor 309= 3 * 103
# Z*309 is cyclic False
#
# factor 310= 2 * 5 * 31
# Z*310 is cyclic False
#
# factor 311= 311
# Z*311 is cyclic True
# smallest generator for Z*311=  17
#
# factor 312= 2^3 * 3 * 13
# Z*312 is cyclic False
#
# factor 313= 313
# Z*313 is cyclic True
# smallest generator for Z*313=  10
#
# factor 314= 2 * 157
# Z*314 is cyclic True
# smallest generator for Z*314=  5
#
# factor 315= 3^2 * 5 * 7
# Z*315 is cyclic False
#
# factor 316= 2^2 * 79
# Z*316 is cyclic False
#
# factor 317= 317
# Z*317 is cyclic True
# smallest generator for Z*317=  2
#
# factor 318= 2 * 3 * 53
# Z*318 is cyclic False
#
# factor 319= 11 * 29
# Z*319 is cyclic False
#
# factor 320= 2^6 * 5
# Z*320 is cyclic False
#
# factor 321= 3 * 107
# Z*321 is cyclic False
#
# factor 322= 2 * 7 * 23
# Z*322 is cyclic False
#
# factor 323= 17 * 19
# Z*323 is cyclic False
#
# factor 324= 2^2 * 3^4
# Z*324 is cyclic False
#
# factor 325= 5^2 * 13
# Z*325 is cyclic False
#
# factor 326= 2 * 163
# Z*326 is cyclic True
# smallest generator for Z*326=  3
#
# factor 327= 3 * 109
# Z*327 is cyclic False
#
# factor 328= 2^3 * 41
# Z*328 is cyclic False
#
# factor 329= 7 * 47
# Z*329 is cyclic False
#
# factor 330= 2 * 3 * 5 * 11
# Z*330 is cyclic False
#
# factor 331= 331
# Z*331 is cyclic True
# smallest generator for Z*331=  3
#
# factor 332= 2^2 * 83
# Z*332 is cyclic False
#
# factor 333= 3^2 * 37
# Z*333 is cyclic False
#
# factor 334= 2 * 167
# Z*334 is cyclic True
# smallest generator for Z*334=  5
#
# factor 335= 5 * 67
# Z*335 is cyclic False
#
# factor 336= 2^4 * 3 * 7
# Z*336 is cyclic False
#
# factor 337= 337
# Z*337 is cyclic True
# smallest generator for Z*337=  10
#
# factor 338= 2 * 13^2
# Z*338 is cyclic True
# smallest generator for Z*338=  7
#
# factor 339= 3 * 113
# Z*339 is cyclic False
#
# factor 340= 2^2 * 5 * 17
# Z*340 is cyclic False
#
# factor 341= 11 * 31
# Z*341 is cyclic False
#
# factor 342= 2 * 3^2 * 19
# Z*342 is cyclic False
#
# factor 343= 7^3
# Z*343 is cyclic True
# smallest generator for Z*343=  3
#
# factor 344= 2^3 * 43
# Z*344 is cyclic False
#
# factor 345= 3 * 5 * 23
# Z*345 is cyclic False
#
# factor 346= 2 * 173
# Z*346 is cyclic True
# smallest generator for Z*346=  3
#
# factor 347= 347
# Z*347 is cyclic True
# smallest generator for Z*347=  2
#
# factor 348= 2^2 * 3 * 29
# Z*348 is cyclic False
#
# factor 349= 349
# Z*349 is cyclic True
# smallest generator for Z*349=  2
#
# factor 350= 2 * 5^2 * 7
# Z*350 is cyclic False
#
# factor 351= 3^3 * 13
# Z*351 is cyclic False
#
# factor 352= 2^5 * 11
# Z*352 is cyclic False
#
# factor 353= 353
# Z*353 is cyclic True
# smallest generator for Z*353=  3
#
# factor 354= 2 * 3 * 59
# Z*354 is cyclic False
#
# factor 355= 5 * 71
# Z*355 is cyclic False
#
# factor 356= 2^2 * 89
# Z*356 is cyclic False
#
# factor 357= 3 * 7 * 17
# Z*357 is cyclic False
#
# factor 358= 2 * 179
# Z*358 is cyclic True
# smallest generator for Z*358=  7
#
# factor 359= 359
# Z*359 is cyclic True
# smallest generator for Z*359=  7
#
# factor 360= 2^3 * 3^2 * 5
# Z*360 is cyclic False
#
# factor 361= 19^2
# Z*361 is cyclic True
# smallest generator for Z*361=  2
#
# factor 362= 2 * 181
# Z*362 is cyclic True
# smallest generator for Z*362=  21
#
# factor 363= 3 * 11^2
# Z*363 is cyclic False
#
# factor 364= 2^2 * 7 * 13
# Z*364 is cyclic False
#
# factor 365= 5 * 73
# Z*365 is cyclic False
#
# factor 366= 2 * 3 * 61
# Z*366 is cyclic False
#
# factor 367= 367
# Z*367 is cyclic True
# smallest generator for Z*367=  6
#
# factor 368= 2^4 * 23
# Z*368 is cyclic False
#
# factor 369= 3^2 * 41
# Z*369 is cyclic False
#
# factor 370= 2 * 5 * 37
# Z*370 is cyclic False
#
# factor 371= 7 * 53
# Z*371 is cyclic False
#
# factor 372= 2^2 * 3 * 31
# Z*372 is cyclic False
#
# factor 373= 373
# Z*373 is cyclic True
# smallest generator for Z*373=  2
#
# factor 374= 2 * 11 * 17
# Z*374 is cyclic False
#
# factor 375= 3 * 5^3
# Z*375 is cyclic False
#
# factor 376= 2^3 * 47
# Z*376 is cyclic False
#
# factor 377= 13 * 29
# Z*377 is cyclic False
#
# factor 378= 2 * 3^3 * 7
# Z*378 is cyclic False
#
# factor 379= 379
# Z*379 is cyclic True
# smallest generator for Z*379=  2
#
# factor 380= 2^2 * 5 * 19
# Z*380 is cyclic False
#
# factor 381= 3 * 127
# Z*381 is cyclic False
#
# factor 382= 2 * 191
# Z*382 is cyclic True
# smallest generator for Z*382=  19
#
# factor 383= 383
# Z*383 is cyclic True
# smallest generator for Z*383=  5
#
# factor 384= 2^7 * 3
# Z*384 is cyclic False
#
# factor 385= 5 * 7 * 11
# Z*385 is cyclic False
#
# factor 386= 2 * 193
# Z*386 is cyclic True
# smallest generator for Z*386=  5
#
# factor 387= 3^2 * 43
# Z*387 is cyclic False
#
# factor 388= 2^2 * 97
# Z*388 is cyclic False
#
# factor 389= 389
# Z*389 is cyclic True
# smallest generator for Z*389=  2
#
# factor 390= 2 * 3 * 5 * 13
# Z*390 is cyclic False
#
# factor 391= 17 * 23
# Z*391 is cyclic False
#
# factor 392= 2^3 * 7^2
# Z*392 is cyclic False
#
# factor 393= 3 * 131
# Z*393 is cyclic False
#
# factor 394= 2 * 197
# Z*394 is cyclic True
# smallest generator for Z*394=  3
#
# factor 395= 5 * 79
# Z*395 is cyclic False
#
# factor 396= 2^2 * 3^2 * 11
# Z*396 is cyclic False
#
# factor 397= 397
# Z*397 is cyclic True
# smallest generator for Z*397=  5
#
# factor 398= 2 * 199
# Z*398 is cyclic True
# smallest generator for Z*398=  3
#
# factor 399= 3 * 7 * 19
# Z*399 is cyclic False
#
# factor 400= 2^4 * 5^2
# Z*400 is cyclic False
#
# factor 401= 401
# Z*401 is cyclic True
# smallest generator for Z*401=  3
#
# factor 402= 2 * 3 * 67
# Z*402 is cyclic False
#
# factor 403= 13 * 31
# Z*403 is cyclic False
#
# factor 404= 2^2 * 101
# Z*404 is cyclic False
#
# factor 405= 3^4 * 5
# Z*405 is cyclic False
#
# factor 406= 2 * 7 * 29
# Z*406 is cyclic False
#
# factor 407= 11 * 37
# Z*407 is cyclic False
#
# factor 408= 2^3 * 3 * 17
# Z*408 is cyclic False
#
# factor 409= 409
# Z*409 is cyclic True
# smallest generator for Z*409=  21
#
# factor 410= 2 * 5 * 41
# Z*410 is cyclic False
#
# factor 411= 3 * 137
# Z*411 is cyclic False
#
# factor 412= 2^2 * 103
# Z*412 is cyclic False
#
# factor 413= 7 * 59
# Z*413 is cyclic False
#
# factor 414= 2 * 3^2 * 23
# Z*414 is cyclic False
#
# factor 415= 5 * 83
# Z*415 is cyclic False
#
# factor 416= 2^5 * 13
# Z*416 is cyclic False
#
# factor 417= 3 * 139
# Z*417 is cyclic False
#
# factor 418= 2 * 11 * 19
# Z*418 is cyclic False
#
# factor 419= 419
# Z*419 is cyclic True
# smallest generator for Z*419=  2
#
# factor 420= 2^2 * 3 * 5 * 7
# Z*420 is cyclic False
#
# factor 421= 421
# Z*421 is cyclic True
# smallest generator for Z*421=  2
#
# factor 422= 2 * 211
# Z*422 is cyclic True
# smallest generator for Z*422=  3
#
# factor 423= 3^2 * 47
# Z*423 is cyclic False
#
# factor 424= 2^3 * 53
# Z*424 is cyclic False
#
# factor 425= 5^2 * 17
# Z*425 is cyclic False
#
# factor 426= 2 * 3 * 71
# Z*426 is cyclic False
#
# factor 427= 7 * 61
# Z*427 is cyclic False
#
# factor 428= 2^2 * 107
# Z*428 is cyclic False
#
# factor 429= 3 * 11 * 13
# Z*429 is cyclic False
#
# factor 430= 2 * 5 * 43
# Z*430 is cyclic False
#
# factor 431= 431
# Z*431 is cyclic True
# smallest generator for Z*431=  7
#
# factor 432= 2^4 * 3^3
# Z*432 is cyclic False
#
# factor 433= 433
# Z*433 is cyclic True
# smallest generator for Z*433=  5
#
# factor 434= 2 * 7 * 31
# Z*434 is cyclic False
#
# factor 435= 3 * 5 * 29
# Z*435 is cyclic False
#
# factor 436= 2^2 * 109
# Z*436 is cyclic False
#
# factor 437= 19 * 23
# Z*437 is cyclic False
#
# factor 438= 2 * 3 * 73
# Z*438 is cyclic False
#
# factor 439= 439
# Z*439 is cyclic True
# smallest generator for Z*439=  15
#
# factor 440= 2^3 * 5 * 11
# Z*440 is cyclic False
#
# factor 441= 3^2 * 7^2
# Z*441 is cyclic False
#
# factor 442= 2 * 13 * 17
# Z*442 is cyclic False
#
# factor 443= 443
# Z*443 is cyclic True
# smallest generator for Z*443=  2
#
# factor 444= 2^2 * 3 * 37
# Z*444 is cyclic False
#
# factor 445= 5 * 89
# Z*445 is cyclic False
#
# factor 446= 2 * 223
# Z*446 is cyclic True
# smallest generator for Z*446=  3
#
# factor 447= 3 * 149
# Z*447 is cyclic False
#
# factor 448= 2^6 * 7
# Z*448 is cyclic False
#
# factor 449= 449
# Z*449 is cyclic True
# smallest generator for Z*449=  3
#
# factor 450= 2 * 3^2 * 5^2
# Z*450 is cyclic False
#
# factor 451= 11 * 41
# Z*451 is cyclic False
#
# factor 452= 2^2 * 113
# Z*452 is cyclic False
#
# factor 453= 3 * 151
# Z*453 is cyclic False
#
# factor 454= 2 * 227
# Z*454 is cyclic True
# smallest generator for Z*454=  5
#
# factor 455= 5 * 7 * 13
# Z*455 is cyclic False
#
# factor 456= 2^3 * 3 * 19
# Z*456 is cyclic False
#
# factor 457= 457
# Z*457 is cyclic True
# smallest generator for Z*457=  13
#
# factor 458= 2 * 229
# Z*458 is cyclic True
# smallest generator for Z*458=  7
#
# factor 459= 3^3 * 17
# Z*459 is cyclic False
#
# factor 460= 2^2 * 5 * 23
# Z*460 is cyclic False
#
# factor 461= 461
# Z*461 is cyclic True
# smallest generator for Z*461=  2
#
# factor 462= 2 * 3 * 7 * 11
# Z*462 is cyclic False
#
# factor 463= 463
# Z*463 is cyclic True
# smallest generator for Z*463=  3
#
# factor 464= 2^4 * 29
# Z*464 is cyclic False
#
# factor 465= 3 * 5 * 31
# Z*465 is cyclic False
#
# factor 466= 2 * 233
# Z*466 is cyclic True
# smallest generator for Z*466=  3
#
# factor 467= 467
# Z*467 is cyclic True
# smallest generator for Z*467=  2
#
# factor 468= 2^2 * 3^2 * 13
# Z*468 is cyclic False
#
# factor 469= 7 * 67
# Z*469 is cyclic False
#
# factor 470= 2 * 5 * 47
# Z*470 is cyclic False
#
# factor 471= 3 * 157
# Z*471 is cyclic False
#
# factor 472= 2^3 * 59
# Z*472 is cyclic False
#
# factor 473= 11 * 43
# Z*473 is cyclic False
#
# factor 474= 2 * 3 * 79
# Z*474 is cyclic False
#
# factor 475= 5^2 * 19
# Z*475 is cyclic False
#
# factor 476= 2^2 * 7 * 17
# Z*476 is cyclic False
#
# factor 477= 3^2 * 53
# Z*477 is cyclic False
#
# factor 478= 2 * 239
# Z*478 is cyclic True
# smallest generator for Z*478=  7
#
# factor 479= 479
# Z*479 is cyclic True
# smallest generator for Z*479=  13
#
# factor 480= 2^5 * 3 * 5
# Z*480 is cyclic False
#
# factor 481= 13 * 37
# Z*481 is cyclic False
#
# factor 482= 2 * 241
# Z*482 is cyclic True
# smallest generator for Z*482=  7
#
# factor 483= 3 * 7 * 23
# Z*483 is cyclic False
#
# factor 484= 2^2 * 11^2
# Z*484 is cyclic False
#
# factor 485= 5 * 97
# Z*485 is cyclic False
#
# factor 486= 2 * 3^5
# Z*486 is cyclic True
# smallest generator for Z*486=  5
#
# factor 487= 487
# Z*487 is cyclic True
# smallest generator for Z*487=  3
#
# factor 488= 2^3 * 61
# Z*488 is cyclic False
#
# factor 489= 3 * 163
# Z*489 is cyclic False
#
# factor 490= 2 * 5 * 7^2
# Z*490 is cyclic False
#
# factor 491= 491
# Z*491 is cyclic True
# smallest generator for Z*491=  2
#
# factor 492= 2^2 * 3 * 41
# Z*492 is cyclic False
#
# factor 493= 17 * 29
# Z*493 is cyclic False
#
# factor 494= 2 * 13 * 19
# Z*494 is cyclic False
#
# factor 495= 3^2 * 5 * 11
# Z*495 is cyclic False
#
# factor 496= 2^4 * 31
# Z*496 is cyclic False
#
# factor 497= 7 * 71
# Z*497 is cyclic False
#
# factor 498= 2 * 3 * 83
# Z*498 is cyclic False
#
# factor 499= 499
# Z*499 is cyclic True
# smallest generator for Z*499=  7
#
# factor 500= 2^2 * 5^3
# Z*500 is cyclic False
#
# factor 501= 3 * 167
# Z*501 is cyclic False
#
# factor 502= 2 * 251
# Z*502 is cyclic True
# smallest generator for Z*502=  11
#
# factor 503= 503
# Z*503 is cyclic True
# smallest generator for Z*503=  5
#
# factor 504= 2^3 * 3^2 * 7
# Z*504 is cyclic False
#
# factor 505= 5 * 101
# Z*505 is cyclic False
#
# factor 506= 2 * 11 * 23
# Z*506 is cyclic False
#
# factor 507= 3 * 13^2
# Z*507 is cyclic False
#
# factor 508= 2^2 * 127
# Z*508 is cyclic False
#
# factor 509= 509
# Z*509 is cyclic True
# smallest generator for Z*509=  2
#
# factor 510= 2 * 3 * 5 * 17
# Z*510 is cyclic False
#
# factor 511= 7 * 73
# Z*511 is cyclic False
#
# factor 512= 2^9
# Z*512 is cyclic False
#
# factor 513= 3^3 * 19
# Z*513 is cyclic False
#
# factor 514= 2 * 257
# Z*514 is cyclic True
# smallest generator for Z*514=  3
#
# factor 515= 5 * 103
# Z*515 is cyclic False
#
# factor 516= 2^2 * 3 * 43
# Z*516 is cyclic False
#
# factor 517= 11 * 47
# Z*517 is cyclic False
#
# factor 518= 2 * 7 * 37
# Z*518 is cyclic False
#
# factor 519= 3 * 173
# Z*519 is cyclic False
#
# factor 520= 2^3 * 5 * 13
# Z*520 is cyclic False
#
# factor 521= 521
# Z*521 is cyclic True
# smallest generator for Z*521=  3
#
# factor 522= 2 * 3^2 * 29
# Z*522 is cyclic False
#
# factor 523= 523
# Z*523 is cyclic True
# smallest generator for Z*523=  2
#
# factor 524= 2^2 * 131
# Z*524 is cyclic False
#
# factor 525= 3 * 5^2 * 7
# Z*525 is cyclic False
#
# factor 526= 2 * 263
# Z*526 is cyclic True
# smallest generator for Z*526=  5
#
# factor 527= 17 * 31
# Z*527 is cyclic False
#
# factor 528= 2^4 * 3 * 11
# Z*528 is cyclic False
#
# factor 529= 23^2
# Z*529 is cyclic True
# smallest generator for Z*529=  5
#
# factor 530= 2 * 5 * 53
# Z*530 is cyclic False
#
# factor 531= 3^2 * 59
# Z*531 is cyclic False
#
# factor 532= 2^2 * 7 * 19
# Z*532 is cyclic False
#
# factor 533= 13 * 41
# Z*533 is cyclic False
#
# factor 534= 2 * 3 * 89
# Z*534 is cyclic False
#
# factor 535= 5 * 107
# Z*535 is cyclic False
#
# factor 536= 2^3 * 67
# Z*536 is cyclic False
#
# factor 537= 3 * 179
# Z*537 is cyclic False
#
# factor 538= 2 * 269
# Z*538 is cyclic True
# smallest generator for Z*538=  3
#
# factor 539= 7^2 * 11
# Z*539 is cyclic False
#
# factor 540= 2^2 * 3^3 * 5
# Z*540 is cyclic False
#
# factor 541= 541
# Z*541 is cyclic True
# smallest generator for Z*541=  2
#
# factor 542= 2 * 271
# Z*542 is cyclic True
# smallest generator for Z*542=  15
#
# factor 543= 3 * 181
# Z*543 is cyclic False
#
# factor 544= 2^5 * 17
# Z*544 is cyclic False
#
# factor 545= 5 * 109
# Z*545 is cyclic False
#
# factor 546= 2 * 3 * 7 * 13
# Z*546 is cyclic False
#
# factor 547= 547
# Z*547 is cyclic True
# smallest generator for Z*547=  2
#
# factor 548= 2^2 * 137
# Z*548 is cyclic False
#
# factor 549= 3^2 * 61
# Z*549 is cyclic False
#
# factor 550= 2 * 5^2 * 11
# Z*550 is cyclic False
#
# factor 551= 19 * 29
# Z*551 is cyclic False
#
# factor 552= 2^3 * 3 * 23
# Z*552 is cyclic False
#
# factor 553= 7 * 79
# Z*553 is cyclic False
#
# factor 554= 2 * 277
# Z*554 is cyclic True
# smallest generator for Z*554=  5
#
# factor 555= 3 * 5 * 37
# Z*555 is cyclic False
#
# factor 556= 2^2 * 139
# Z*556 is cyclic False
#
# factor 557= 557
# Z*557 is cyclic True
# smallest generator for Z*557=  2
#
# factor 558= 2 * 3^2 * 31
# Z*558 is cyclic False
#
# factor 559= 13 * 43
# Z*559 is cyclic False
#
# factor 560= 2^4 * 5 * 7
# Z*560 is cyclic False
#
# factor 561= 3 * 11 * 17
# Z*561 is cyclic False
#
# factor 562= 2 * 281
# Z*562 is cyclic True
# smallest generator for Z*562=  3
#
# factor 563= 563
# Z*563 is cyclic True
# smallest generator for Z*563=  2
#
# factor 564= 2^2 * 3 * 47
# Z*564 is cyclic False
#
# factor 565= 5 * 113
# Z*565 is cyclic False
#
# factor 566= 2 * 283
# Z*566 is cyclic True
# smallest generator for Z*566=  3
#
# factor 567= 3^4 * 7
# Z*567 is cyclic False
#
# factor 568= 2^3 * 71
# Z*568 is cyclic False
#
# factor 569= 569
# Z*569 is cyclic True
# smallest generator for Z*569=  3
#
# factor 570= 2 * 3 * 5 * 19
# Z*570 is cyclic False
#
# factor 571= 571
# Z*571 is cyclic True
# smallest generator for Z*571=  3
#
# factor 572= 2^2 * 11 * 13
# Z*572 is cyclic False
#
# factor 573= 3 * 191
# Z*573 is cyclic False
#
# factor 574= 2 * 7 * 41
# Z*574 is cyclic False
#
# factor 575= 5^2 * 23
# Z*575 is cyclic False
#
# factor 576= 2^6 * 3^2
# Z*576 is cyclic False
#
# factor 577= 577
# Z*577 is cyclic True
# smallest generator for Z*577=  5
#
# factor 578= 2 * 17^2
# Z*578 is cyclic True
# smallest generator for Z*578=  3
#
# factor 579= 3 * 193
# Z*579 is cyclic False
#
# factor 580= 2^2 * 5 * 29
# Z*580 is cyclic False
#
# factor 581= 7 * 83
# Z*581 is cyclic False
#
# factor 582= 2 * 3 * 97
# Z*582 is cyclic False
#
# factor 583= 11 * 53
# Z*583 is cyclic False
#
# factor 584= 2^3 * 73
# Z*584 is cyclic False
#
# factor 585= 3^2 * 5 * 13
# Z*585 is cyclic False
#
# factor 586= 2 * 293
# Z*586 is cyclic True
# smallest generator for Z*586=  3
#
# factor 587= 587
# Z*587 is cyclic True
# smallest generator for Z*587=  2
#
# factor 588= 2^2 * 3 * 7^2
# Z*588 is cyclic False
#
# factor 589= 19 * 31
# Z*589 is cyclic False
#
# factor 590= 2 * 5 * 59
# Z*590 is cyclic False
#
# factor 591= 3 * 197
# Z*591 is cyclic False
#
# factor 592= 2^4 * 37
# Z*592 is cyclic False
#
# factor 593= 593
# Z*593 is cyclic True
# smallest generator for Z*593=  3
#
# factor 594= 2 * 3^3 * 11
# Z*594 is cyclic False
#
# factor 595= 5 * 7 * 17
# Z*595 is cyclic False
#
# factor 596= 2^2 * 149
# Z*596 is cyclic False
#
# factor 597= 3 * 199
# Z*597 is cyclic False
#
# factor 598= 2 * 13 * 23
# Z*598 is cyclic False
#
# factor 599= 599
# Z*599 is cyclic True
# smallest generator for Z*599=  7
#
# factor 600= 2^3 * 3 * 5^2
# Z*600 is cyclic False
#
# factor 601= 601
# Z*601 is cyclic True
# smallest generator for Z*601=  7
#
# factor 602= 2 * 7 * 43
# Z*602 is cyclic False
#
# factor 603= 3^2 * 67
# Z*603 is cyclic False
#
# factor 604= 2^2 * 151
# Z*604 is cyclic False
#
# factor 605= 5 * 11^2
# Z*605 is cyclic False
#
# factor 606= 2 * 3 * 101
# Z*606 is cyclic False
#
# factor 607= 607
# Z*607 is cyclic True
# smallest generator for Z*607=  3
#
# factor 608= 2^5 * 19
# Z*608 is cyclic False
#
# factor 609= 3 * 7 * 29
# Z*609 is cyclic False
#
# factor 610= 2 * 5 * 61
# Z*610 is cyclic False
#
# factor 611= 13 * 47
# Z*611 is cyclic False
#
# factor 612= 2^2 * 3^2 * 17
# Z*612 is cyclic False
#
# factor 613= 613
# Z*613 is cyclic True
# smallest generator for Z*613=  2
#
# factor 614= 2 * 307
# Z*614 is cyclic True
# smallest generator for Z*614=  5
#
# factor 615= 3 * 5 * 41
# Z*615 is cyclic False
#
# factor 616= 2^3 * 7 * 11
# Z*616 is cyclic False
#
# factor 617= 617
# Z*617 is cyclic True
# smallest generator for Z*617=  3
#
# factor 618= 2 * 3 * 103
# Z*618 is cyclic False
#
# factor 619= 619
# Z*619 is cyclic True
# smallest generator for Z*619=  2
#
# factor 620= 2^2 * 5 * 31
# Z*620 is cyclic False
#
# factor 621= 3^3 * 23
# Z*621 is cyclic False
#
# factor 622= 2 * 311
# Z*622 is cyclic True
# smallest generator for Z*622=  17
#
# factor 623= 7 * 89
# Z*623 is cyclic False
#
# factor 624= 2^4 * 3 * 13
# Z*624 is cyclic False
#
# factor 625= 5^4
# Z*625 is cyclic True
# smallest generator for Z*625=  2
#
# factor 626= 2 * 313
# Z*626 is cyclic True
# smallest generator for Z*626=  15
#
# factor 627= 3 * 11 * 19
# Z*627 is cyclic False
#
# factor 628= 2^2 * 157
# Z*628 is cyclic False
#
# factor 629= 17 * 37
# Z*629 is cyclic False
#
# factor 630= 2 * 3^2 * 5 * 7
# Z*630 is cyclic False
#
# factor 631= 631
# Z*631 is cyclic True
# smallest generator for Z*631=  3
#
# factor 632= 2^3 * 79
# Z*632 is cyclic False
#
# factor 633= 3 * 211
# Z*633 is cyclic False
#
# factor 634= 2 * 317
# Z*634 is cyclic True
# smallest generator for Z*634=  3
#
# factor 635= 5 * 127
# Z*635 is cyclic False
#
# factor 636= 2^2 * 3 * 53
# Z*636 is cyclic False
#
# factor 637= 7^2 * 13
# Z*637 is cyclic False
#
# factor 638= 2 * 11 * 29
# Z*638 is cyclic False
#
# factor 639= 3^2 * 71
# Z*639 is cyclic False
#
# factor 640= 2^7 * 5
# Z*640 is cyclic False
#
# factor 641= 641
# Z*641 is cyclic True
# smallest generator for Z*641=  3
#
# factor 642= 2 * 3 * 107
# Z*642 is cyclic False
#
# factor 643= 643
# Z*643 is cyclic True
# smallest generator for Z*643=  11
#
# factor 644= 2^2 * 7 * 23
# Z*644 is cyclic False
#
# factor 645= 3 * 5 * 43
# Z*645 is cyclic False
#
# factor 646= 2 * 17 * 19
# Z*646 is cyclic False
#
# factor 647= 647
# Z*647 is cyclic True
# smallest generator for Z*647=  5
#
# factor 648= 2^3 * 3^4
# Z*648 is cyclic False
#
# factor 649= 11 * 59
# Z*649 is cyclic False
#
# factor 650= 2 * 5^2 * 13
# Z*650 is cyclic False
#
# factor 651= 3 * 7 * 31
# Z*651 is cyclic False
#
# factor 652= 2^2 * 163
# Z*652 is cyclic False
#
# factor 653= 653
# Z*653 is cyclic True
# smallest generator for Z*653=  2
#
# factor 654= 2 * 3 * 109
# Z*654 is cyclic False
#
# factor 655= 5 * 131
# Z*655 is cyclic False
#
# factor 656= 2^4 * 41
# Z*656 is cyclic False
#
# factor 657= 3^2 * 73
# Z*657 is cyclic False
#
# factor 658= 2 * 7 * 47
# Z*658 is cyclic False
#
# factor 659= 659
# Z*659 is cyclic True
# smallest generator for Z*659=  2
#
# factor 660= 2^2 * 3 * 5 * 11
# Z*660 is cyclic False
#
# factor 661= 661
# Z*661 is cyclic True
# smallest generator for Z*661=  2
#
# factor 662= 2 * 331
# Z*662 is cyclic True
# smallest generator for Z*662=  3
#
# factor 663= 3 * 13 * 17
# Z*663 is cyclic False
#
# factor 664= 2^3 * 83
# Z*664 is cyclic False
#
# factor 665= 5 * 7 * 19
# Z*665 is cyclic False
#
# factor 666= 2 * 3^2 * 37
# Z*666 is cyclic False
#
# factor 667= 23 * 29
# Z*667 is cyclic False
#
# factor 668= 2^2 * 167
# Z*668 is cyclic False
#
# factor 669= 3 * 223
# Z*669 is cyclic False
#
# factor 670= 2 * 5 * 67
# Z*670 is cyclic False
#
# factor 671= 11 * 61
# Z*671 is cyclic False
#
# factor 672= 2^5 * 3 * 7
# Z*672 is cyclic False
#
# factor 673= 673
# Z*673 is cyclic True
# smallest generator for Z*673=  5
#
# factor 674= 2 * 337
# Z*674 is cyclic True
# smallest generator for Z*674=  15
#
# factor 675= 3^3 * 5^2
# Z*675 is cyclic False
#
# factor 676= 2^2 * 13^2
# Z*676 is cyclic False
#
# factor 677= 677
# Z*677 is cyclic True
# smallest generator for Z*677=  2
#
# factor 678= 2 * 3 * 113
# Z*678 is cyclic False
#
# factor 679= 7 * 97
# Z*679 is cyclic False
#
# factor 680= 2^3 * 5 * 17
# Z*680 is cyclic False
#
# factor 681= 3 * 227
# Z*681 is cyclic False
#
# factor 682= 2 * 11 * 31
# Z*682 is cyclic False
#
# factor 683= 683
# Z*683 is cyclic True
# smallest generator for Z*683=  5
#
# factor 684= 2^2 * 3^2 * 19
# Z*684 is cyclic False
#
# factor 685= 5 * 137
# Z*685 is cyclic False
#
# factor 686= 2 * 7^3
# Z*686 is cyclic True
# smallest generator for Z*686=  3
#
# factor 687= 3 * 229
# Z*687 is cyclic False
#
# factor 688= 2^4 * 43
# Z*688 is cyclic False
#
# factor 689= 13 * 53
# Z*689 is cyclic False
#
# factor 690= 2 * 3 * 5 * 23
# Z*690 is cyclic False
#
# factor 691= 691
# Z*691 is cyclic True
# smallest generator for Z*691=  3
#
# factor 692= 2^2 * 173
# Z*692 is cyclic False
#
# factor 693= 3^2 * 7 * 11
# Z*693 is cyclic False
#
# factor 694= 2 * 347
# Z*694 is cyclic True
# smallest generator for Z*694=  5
#
# factor 695= 5 * 139
# Z*695 is cyclic False
#
# factor 696= 2^3 * 3 * 29
# Z*696 is cyclic False
#
# factor 697= 17 * 41
# Z*697 is cyclic False
#
# factor 698= 2 * 349
# Z*698 is cyclic True
# smallest generator for Z*698=  7
#
# factor 699= 3 * 233
# Z*699 is cyclic False
#
# factor 700= 2^2 * 5^2 * 7
# Z*700 is cyclic False
#
# factor 701= 701
# Z*701 is cyclic True
# smallest generator for Z*701=  2
#
# factor 702= 2 * 3^3 * 13
# Z*702 is cyclic False
#
# factor 703= 19 * 37
# Z*703 is cyclic False
#
# factor 704= 2^6 * 11
# Z*704 is cyclic False
#
# factor 705= 3 * 5 * 47
# Z*705 is cyclic False
#
# factor 706= 2 * 353
# Z*706 is cyclic True
# smallest generator for Z*706=  3
#
# factor 707= 7 * 101
# Z*707 is cyclic False
#
# factor 708= 2^2 * 3 * 59
# Z*708 is cyclic False
#
# factor 709= 709
# Z*709 is cyclic True
# smallest generator for Z*709=  2
#
# factor 710= 2 * 5 * 71
# Z*710 is cyclic False
#
# factor 711= 3^2 * 79
# Z*711 is cyclic False
#
# factor 712= 2^3 * 89
# Z*712 is cyclic False
#
# factor 713= 23 * 31
# Z*713 is cyclic False
#
# factor 714= 2 * 3 * 7 * 17
# Z*714 is cyclic False
#
# factor 715= 5 * 11 * 13
# Z*715 is cyclic False
#
# factor 716= 2^2 * 179
# Z*716 is cyclic False
#
# factor 717= 3 * 239
# Z*717 is cyclic False
#
# factor 718= 2 * 359
# Z*718 is cyclic True
# smallest generator for Z*718=  7
#
# factor 719= 719
# Z*719 is cyclic True
# smallest generator for Z*719=  11
#
# factor 720= 2^4 * 3^2 * 5
# Z*720 is cyclic False
#
# factor 721= 7 * 103
# Z*721 is cyclic False
#
# factor 722= 2 * 19^2
# Z*722 is cyclic True
# smallest generator for Z*722=  3
#
# factor 723= 3 * 241
# Z*723 is cyclic False
#
# factor 724= 2^2 * 181
# Z*724 is cyclic False
#
# factor 725= 5^2 * 29
# Z*725 is cyclic False
#
# factor 726= 2 * 3 * 11^2
# Z*726 is cyclic False
#
# factor 727= 727
# Z*727 is cyclic True
# smallest generator for Z*727=  5
#
# factor 728= 2^3 * 7 * 13
# Z*728 is cyclic False
#
# factor 729= 3^6
# Z*729 is cyclic True
# smallest generator for Z*729=  2
#
# factor 730= 2 * 5 * 73
# Z*730 is cyclic False
#
# factor 731= 17 * 43
# Z*731 is cyclic False
#
# factor 732= 2^2 * 3 * 61
# Z*732 is cyclic False
#
# factor 733= 733
# Z*733 is cyclic True
# smallest generator for Z*733=  6
#
# factor 734= 2 * 367
# Z*734 is cyclic True
# smallest generator for Z*734=  11
#
# factor 735= 3 * 5 * 7^2
# Z*735 is cyclic False
#
# factor 736= 2^5 * 23
# Z*736 is cyclic False
#
# factor 737= 11 * 67
# Z*737 is cyclic False
#
# factor 738= 2 * 3^2 * 41
# Z*738 is cyclic False
#
# factor 739= 739
# Z*739 is cyclic True
# smallest generator for Z*739=  3
#
# factor 740= 2^2 * 5 * 37
# Z*740 is cyclic False
#
# factor 741= 3 * 13 * 19
# Z*741 is cyclic False
#
# factor 742= 2 * 7 * 53
# Z*742 is cyclic False
#
# factor 743= 743
# Z*743 is cyclic True
# smallest generator for Z*743=  5
#
# factor 744= 2^3 * 3 * 31
# Z*744 is cyclic False
#
# factor 745= 5 * 149
# Z*745 is cyclic False
#
# factor 746= 2 * 373
# Z*746 is cyclic True
# smallest generator for Z*746=  5
#
# factor 747= 3^2 * 83
# Z*747 is cyclic False
#
# factor 748= 2^2 * 11 * 17
# Z*748 is cyclic False
#
# factor 749= 7 * 107
# Z*749 is cyclic False
#
# factor 750= 2 * 3 * 5^3
# Z*750 is cyclic False
#
# factor 751= 751
# Z*751 is cyclic True
# smallest generator for Z*751=  3
#
# factor 752= 2^4 * 47
# Z*752 is cyclic False
#
# factor 753= 3 * 251
# Z*753 is cyclic False
#
# factor 754= 2 * 13 * 29
# Z*754 is cyclic False
#
# factor 755= 5 * 151
# Z*755 is cyclic False
#
# factor 756= 2^2 * 3^3 * 7
# Z*756 is cyclic False
#
# factor 757= 757
# Z*757 is cyclic True
# smallest generator for Z*757=  2
#
# factor 758= 2 * 379
# Z*758 is cyclic True
# smallest generator for Z*758=  3
#
# factor 759= 3 * 11 * 23
# Z*759 is cyclic False
#
# factor 760= 2^3 * 5 * 19
# Z*760 is cyclic False
#
# factor 761= 761
# Z*761 is cyclic True
# smallest generator for Z*761=  6
#
# factor 762= 2 * 3 * 127
# Z*762 is cyclic False
#
# factor 763= 7 * 109
# Z*763 is cyclic False
#
# factor 764= 2^2 * 191
# Z*764 is cyclic False
#
# factor 765= 3^2 * 5 * 17
# Z*765 is cyclic False
#
# factor 766= 2 * 383
# Z*766 is cyclic True
# smallest generator for Z*766=  5
#
# factor 767= 13 * 59
# Z*767 is cyclic False
#
# factor 768= 2^8 * 3
# Z*768 is cyclic False
#
# factor 769= 769
# Z*769 is cyclic True
# smallest generator for Z*769=  11
#
# factor 770= 2 * 5 * 7 * 11
# Z*770 is cyclic False
#
# factor 771= 3 * 257
# Z*771 is cyclic False
#
# factor 772= 2^2 * 193
# Z*772 is cyclic False
#
# factor 773= 773
# Z*773 is cyclic True
# smallest generator for Z*773=  2
#
# factor 774= 2 * 3^2 * 43
# Z*774 is cyclic False
#
# factor 775= 5^2 * 31
# Z*775 is cyclic False
#
# factor 776= 2^3 * 97
# Z*776 is cyclic False
#
# factor 777= 3 * 7 * 37
# Z*777 is cyclic False
#
# factor 778= 2 * 389
# Z*778 is cyclic True
# smallest generator for Z*778=  3
#
# factor 779= 19 * 41
# Z*779 is cyclic False
#
# factor 780= 2^2 * 3 * 5 * 13
# Z*780 is cyclic False
#
# factor 781= 11 * 71
# Z*781 is cyclic False
#
# factor 782= 2 * 17 * 23
# Z*782 is cyclic False
#
# factor 783= 3^3 * 29
# Z*783 is cyclic False
#
# factor 784= 2^4 * 7^2
# Z*784 is cyclic False
#
# factor 785= 5 * 157
# Z*785 is cyclic False
#
# factor 786= 2 * 3 * 131
# Z*786 is cyclic False
#
# factor 787= 787
# Z*787 is cyclic True
# smallest generator for Z*787=  2
#
# factor 788= 2^2 * 197
# Z*788 is cyclic False
#
# factor 789= 3 * 263
# Z*789 is cyclic False
#
# factor 790= 2 * 5 * 79
# Z*790 is cyclic False
#
# factor 791= 7 * 113
# Z*791 is cyclic False
#
# factor 792= 2^3 * 3^2 * 11
# Z*792 is cyclic False
#
# factor 793= 13 * 61
# Z*793 is cyclic False
#
# factor 794= 2 * 397
# Z*794 is cyclic True
# smallest generator for Z*794=  5
#
# factor 795= 3 * 5 * 53
# Z*795 is cyclic False
#
# factor 796= 2^2 * 199
# Z*796 is cyclic False
#
# factor 797= 797
# Z*797 is cyclic True
# smallest generator for Z*797=  2
#
# factor 798= 2 * 3 * 7 * 19
# Z*798 is cyclic False
#
# factor 799= 17 * 47
# Z*799 is cyclic False
#
# factor 800= 2^5 * 5^2
# Z*800 is cyclic False
#
# factor 801= 3^2 * 89
# Z*801 is cyclic False
#
# factor 802= 2 * 401
# Z*802 is cyclic True
# smallest generator for Z*802=  3
#
# factor 803= 11 * 73
# Z*803 is cyclic False
#
# factor 804= 2^2 * 3 * 67
# Z*804 is cyclic False
#
# factor 805= 5 * 7 * 23
# Z*805 is cyclic False
#
# factor 806= 2 * 13 * 31
# Z*806 is cyclic False
#
# factor 807= 3 * 269
# Z*807 is cyclic False
#
# factor 808= 2^3 * 101
# Z*808 is cyclic False
#
# factor 809= 809
# Z*809 is cyclic True
# smallest generator for Z*809=  3
#
# factor 810= 2 * 3^4 * 5
# Z*810 is cyclic False
#
# factor 811= 811
# Z*811 is cyclic True
# smallest generator for Z*811=  3
#
# factor 812= 2^2 * 7 * 29
# Z*812 is cyclic False
#
# factor 813= 3 * 271
# Z*813 is cyclic False
#
# factor 814= 2 * 11 * 37
# Z*814 is cyclic False
#
# factor 815= 5 * 163
# Z*815 is cyclic False
#
# factor 816= 2^4 * 3 * 17
# Z*816 is cyclic False
#
# factor 817= 19 * 43
# Z*817 is cyclic False
#
# factor 818= 2 * 409
# Z*818 is cyclic True
# smallest generator for Z*818=  21
#
# factor 819= 3^2 * 7 * 13
# Z*819 is cyclic False
#
# factor 820= 2^2 * 5 * 41
# Z*820 is cyclic False
#
# factor 821= 821
# Z*821 is cyclic True
# smallest generator for Z*821=  2
#
# factor 822= 2 * 3 * 137
# Z*822 is cyclic False
#
# factor 823= 823
# Z*823 is cyclic True
# smallest generator for Z*823=  3
#
# factor 824= 2^3 * 103
# Z*824 is cyclic False
#
# factor 825= 3 * 5^2 * 11
# Z*825 is cyclic False
#
# factor 826= 2 * 7 * 59
# Z*826 is cyclic False
#
# factor 827= 827
# Z*827 is cyclic True
# smallest generator for Z*827=  2
#
# factor 828= 2^2 * 3^2 * 23
# Z*828 is cyclic False
#
# factor 829= 829
# Z*829 is cyclic True
# smallest generator for Z*829=  2
#
# factor 830= 2 * 5 * 83
# Z*830 is cyclic False
#
# factor 831= 3 * 277
# Z*831 is cyclic False
#
# factor 832= 2^6 * 13
# Z*832 is cyclic False
#
# factor 833= 7^2 * 17
# Z*833 is cyclic False
#
# factor 834= 2 * 3 * 139
# Z*834 is cyclic False
#
# factor 835= 5 * 167
# Z*835 is cyclic False
#
# factor 836= 2^2 * 11 * 19
# Z*836 is cyclic False
#
# factor 837= 3^3 * 31
# Z*837 is cyclic False
#
# factor 838= 2 * 419
# Z*838 is cyclic True
# smallest generator for Z*838=  11
#
# factor 839= 839
# Z*839 is cyclic True
# smallest generator for Z*839=  11
#
# factor 840= 2^3 * 3 * 5 * 7
# Z*840 is cyclic False
#
# factor 841= 29^2
# Z*841 is cyclic True
# smallest generator for Z*841=  2
#
# factor 842= 2 * 421
# Z*842 is cyclic True
# smallest generator for Z*842=  23
#
# factor 843= 3 * 281
# Z*843 is cyclic False
#
# factor 844= 2^2 * 211
# Z*844 is cyclic False
#
# factor 845= 5 * 13^2
# Z*845 is cyclic False
#
# factor 846= 2 * 3^2 * 47
# Z*846 is cyclic False
#
# factor 847= 7 * 11^2
# Z*847 is cyclic False
#
# factor 848= 2^4 * 53
# Z*848 is cyclic False
#
# factor 849= 3 * 283
# Z*849 is cyclic False
#
# factor 850= 2 * 5^2 * 17
# Z*850 is cyclic False
#
# factor 851= 23 * 37
# Z*851 is cyclic False
#
# factor 852= 2^2 * 3 * 71
# Z*852 is cyclic False
#
# factor 853= 853
# Z*853 is cyclic True
# smallest generator for Z*853=  2
#
# factor 854= 2 * 7 * 61
# Z*854 is cyclic False
#
# factor 855= 3^2 * 5 * 19
# Z*855 is cyclic False
#
# factor 856= 2^3 * 107
# Z*856 is cyclic False
#
# factor 857= 857
# Z*857 is cyclic True
# smallest generator for Z*857=  3
#
# factor 858= 2 * 3 * 11 * 13
# Z*858 is cyclic False
#
# factor 859= 859
# Z*859 is cyclic True
# smallest generator for Z*859=  2
#
# factor 860= 2^2 * 5 * 43
# Z*860 is cyclic False
#
# factor 861= 3 * 7 * 41
# Z*861 is cyclic False
#
# factor 862= 2 * 431
# Z*862 is cyclic True
# smallest generator for Z*862=  7
#
# factor 863= 863
# Z*863 is cyclic True
# smallest generator for Z*863=  5
#
# factor 864= 2^5 * 3^3
# Z*864 is cyclic False
#
# factor 865= 5 * 173
# Z*865 is cyclic False
#
# factor 866= 2 * 433
# Z*866 is cyclic True
# smallest generator for Z*866=  5
#
# factor 867= 3 * 17^2
# Z*867 is cyclic False
#
# factor 868= 2^2 * 7 * 31
# Z*868 is cyclic False
#
# factor 869= 11 * 79
# Z*869 is cyclic False
#
# factor 870= 2 * 3 * 5 * 29
# Z*870 is cyclic False
#
# factor 871= 13 * 67
# Z*871 is cyclic False
#
# factor 872= 2^3 * 109
# Z*872 is cyclic False
#
# factor 873= 3^2 * 97
# Z*873 is cyclic False
#
# factor 874= 2 * 19 * 23
# Z*874 is cyclic False
#
# factor 875= 5^3 * 7
# Z*875 is cyclic False
#
# factor 876= 2^2 * 3 * 73
# Z*876 is cyclic False
#
# factor 877= 877
# Z*877 is cyclic True
# smallest generator for Z*877=  2
#
# factor 878= 2 * 439
# Z*878 is cyclic True
# smallest generator for Z*878=  15
#
# factor 879= 3 * 293
# Z*879 is cyclic False
#
# factor 880= 2^4 * 5 * 11
# Z*880 is cyclic False
#
# factor 881= 881
# Z*881 is cyclic True
# smallest generator for Z*881=  3
#
# factor 882= 2 * 3^2 * 7^2
# Z*882 is cyclic False
#
# factor 883= 883
# Z*883 is cyclic True
# smallest generator for Z*883=  2
#
# factor 884= 2^2 * 13 * 17
# Z*884 is cyclic False
#
# factor 885= 3 * 5 * 59
# Z*885 is cyclic False
#
# factor 886= 2 * 443
# Z*886 is cyclic True
# smallest generator for Z*886=  5
#
# factor 887= 887
# Z*887 is cyclic True
# smallest generator for Z*887=  5
#
# factor 888= 2^3 * 3 * 37
# Z*888 is cyclic False
#
# factor 889= 7 * 127
# Z*889 is cyclic False
#
# factor 890= 2 * 5 * 89
# Z*890 is cyclic False
#
# factor 891= 3^4 * 11
# Z*891 is cyclic False
#
# factor 892= 2^2 * 223
# Z*892 is cyclic False
#
# factor 893= 19 * 47
# Z*893 is cyclic False
#
# factor 894= 2 * 3 * 149
# Z*894 is cyclic False
#
# factor 895= 5 * 179
# Z*895 is cyclic False
#
# factor 896= 2^7 * 7
# Z*896 is cyclic False
#
# factor 897= 3 * 13 * 23
# Z*897 is cyclic False
#
# factor 898= 2 * 449
# Z*898 is cyclic True
# smallest generator for Z*898=  3
#
# factor 899= 29 * 31
# Z*899 is cyclic False
#
# factor 900= 2^2 * 3^2 * 5^2
# Z*900 is cyclic False
#
# factor 901= 17 * 53
# Z*901 is cyclic False
#
# factor 902= 2 * 11 * 41
# Z*902 is cyclic False
#
# factor 903= 3 * 7 * 43
# Z*903 is cyclic False
#
# factor 904= 2^3 * 113
# Z*904 is cyclic False
#
# factor 905= 5 * 181
# Z*905 is cyclic False
#
# factor 906= 2 * 3 * 151
# Z*906 is cyclic False
#
# factor 907= 907
# Z*907 is cyclic True
# smallest generator for Z*907=  2
#
# factor 908= 2^2 * 227
# Z*908 is cyclic False
#
# factor 909= 3^2 * 101
# Z*909 is cyclic False
#
# factor 910= 2 * 5 * 7 * 13
# Z*910 is cyclic False
#
# factor 911= 911
# Z*911 is cyclic True
# smallest generator for Z*911=  17
#
# factor 912= 2^4 * 3 * 19
# Z*912 is cyclic False
#
# factor 913= 11 * 83
# Z*913 is cyclic False
#
# factor 914= 2 * 457
# Z*914 is cyclic True
# smallest generator for Z*914=  13
#
# factor 915= 3 * 5 * 61
# Z*915 is cyclic False
#
# factor 916= 2^2 * 229
# Z*916 is cyclic False
#
# factor 917= 7 * 131
# Z*917 is cyclic False
#
# factor 918= 2 * 3^3 * 17
# Z*918 is cyclic False
#
# factor 919= 919
# Z*919 is cyclic True
# smallest generator for Z*919=  7
#
# factor 920= 2^3 * 5 * 23
# Z*920 is cyclic False
#
# factor 921= 3 * 307
# Z*921 is cyclic False
#
# factor 922= 2 * 461
# Z*922 is cyclic True
# smallest generator for Z*922=  3
#
# factor 923= 13 * 71
# Z*923 is cyclic False
#
# factor 924= 2^2 * 3 * 7 * 11
# Z*924 is cyclic False
#
# factor 925= 5^2 * 37
# Z*925 is cyclic False
#
# factor 926= 2 * 463
# Z*926 is cyclic True
# smallest generator for Z*926=  3
#
# factor 927= 3^2 * 103
# Z*927 is cyclic False
#
# factor 928= 2^5 * 29
# Z*928 is cyclic False
#
# factor 929= 929
# Z*929 is cyclic True
# smallest generator for Z*929=  3
#
# factor 930= 2 * 3 * 5 * 31
# Z*930 is cyclic False
#
# factor 931= 7^2 * 19
# Z*931 is cyclic False
#
# factor 932= 2^2 * 233
# Z*932 is cyclic False
#
# factor 933= 3 * 311
# Z*933 is cyclic False
#
# factor 934= 2 * 467
# Z*934 is cyclic True
# smallest generator for Z*934=  5
#
# factor 935= 5 * 11 * 17
# Z*935 is cyclic False
#
# factor 936= 2^3 * 3^2 * 13
# Z*936 is cyclic False
#
# factor 937= 937
# Z*937 is cyclic True
# smallest generator for Z*937=  5
#
# factor 938= 2 * 7 * 67
# Z*938 is cyclic False
#
# factor 939= 3 * 313
# Z*939 is cyclic False
#
# factor 940= 2^2 * 5 * 47
# Z*940 is cyclic False
#
# factor 941= 941
# Z*941 is cyclic True
# smallest generator for Z*941=  2
#
# factor 942= 2 * 3 * 157
# Z*942 is cyclic False
#
# factor 943= 23 * 41
# Z*943 is cyclic False
#
# factor 944= 2^4 * 59
# Z*944 is cyclic False
#
# factor 945= 3^3 * 5 * 7
# Z*945 is cyclic False
#
# factor 946= 2 * 11 * 43
# Z*946 is cyclic False
#
# factor 947= 947
# Z*947 is cyclic True
# smallest generator for Z*947=  2
#
# factor 948= 2^2 * 3 * 79
# Z*948 is cyclic False
#
# factor 949= 13 * 73
# Z*949 is cyclic False
#
# factor 950= 2 * 5^2 * 19
# Z*950 is cyclic False
#
# factor 951= 3 * 317
# Z*951 is cyclic False
#
# factor 952= 2^3 * 7 * 17
# Z*952 is cyclic False
#
# factor 953= 953
# Z*953 is cyclic True
# smallest generator for Z*953=  3
#
# factor 954= 2 * 3^2 * 53
# Z*954 is cyclic False
#
# factor 955= 5 * 191
# Z*955 is cyclic False
#
# factor 956= 2^2 * 239
# Z*956 is cyclic False
#
# factor 957= 3 * 11 * 29
# Z*957 is cyclic False
#
# factor 958= 2 * 479
# Z*958 is cyclic True
# smallest generator for Z*958=  13
#
# factor 959= 7 * 137
# Z*959 is cyclic False
#
# factor 960= 2^6 * 3 * 5
# Z*960 is cyclic False
#
# factor 961= 31^2
# Z*961 is cyclic True
# smallest generator for Z*961=  3
#
# factor 962= 2 * 13 * 37
# Z*962 is cyclic False
#
# factor 963= 3^2 * 107
# Z*963 is cyclic False
#
# factor 964= 2^2 * 241
# Z*964 is cyclic False
#
# factor 965= 5 * 193
# Z*965 is cyclic False
#
# factor 966= 2 * 3 * 7 * 23
# Z*966 is cyclic False
#
# factor 967= 967
# Z*967 is cyclic True
# smallest generator for Z*967=  5
#
# factor 968= 2^3 * 11^2
# Z*968 is cyclic False
#
# factor 969= 3 * 17 * 19
# Z*969 is cyclic False
#
# factor 970= 2 * 5 * 97
# Z*970 is cyclic False
#
# factor 971= 971
# Z*971 is cyclic True
# smallest generator for Z*971=  6
#
# factor 972= 2^2 * 3^5
# Z*972 is cyclic False
#
# factor 973= 7 * 139
# Z*973 is cyclic False
#
# factor 974= 2 * 487
# Z*974 is cyclic True
# smallest generator for Z*974=  3
#
# factor 975= 3 * 5^2 * 13
# Z*975 is cyclic False
#
# factor 976= 2^4 * 61
# Z*976 is cyclic False
#
# factor 977= 977
# Z*977 is cyclic True
# smallest generator for Z*977=  3
#
# factor 978= 2 * 3 * 163
# Z*978 is cyclic False
#
# factor 979= 11 * 89
# Z*979 is cyclic False
#
# factor 980= 2^2 * 5 * 7^2
# Z*980 is cyclic False
#
# factor 981= 3^2 * 109
# Z*981 is cyclic False
#
# factor 982= 2 * 491
# Z*982 is cyclic True
# smallest generator for Z*982=  7
#
# factor 983= 983
# Z*983 is cyclic True
# smallest generator for Z*983=  5
#
# factor 984= 2^3 * 3 * 41
# Z*984 is cyclic False
#
# factor 985= 5 * 197
# Z*985 is cyclic False
#
# factor 986= 2 * 17 * 29
# Z*986 is cyclic False
#
# factor 987= 3 * 7 * 47
# Z*987 is cyclic False
#
# factor 988= 2^2 * 13 * 19
# Z*988 is cyclic False
#
# factor 989= 23 * 43
# Z*989 is cyclic False
#
# factor 990= 2 * 3^2 * 5 * 11
# Z*990 is cyclic False
#
# factor 991= 991
# Z*991 is cyclic True
# smallest generator for Z*991=  6
#
# factor 992= 2^5 * 31
# Z*992 is cyclic False
#
# factor 993= 3 * 331
# Z*993 is cyclic False
#
# factor 994= 2 * 7 * 71
# Z*994 is cyclic False
#
# factor 995= 5 * 199
# Z*995 is cyclic False
#
# factor 996= 2^2 * 3 * 83
# Z*996 is cyclic False
#
# factor 997= 997
# Z*997 is cyclic True
# smallest generator for Z*997=  7
#
# factor 998= 2 * 499
# Z*998 is cyclic True
# smallest generator for Z*998=  7
#
# factor 999= 3^3 * 37
# Z*999 is cyclic False
#
# factor 1000= 2^3 * 5^3
# Z*1000 is cyclic False

# %% [markdown]
# ---
# ### 6*. Циклічна чи ні?
#
# Розглянемо підгрупу $G$ групи $GL_2(\mathbb{Z})$, породжену двома матрицями:
#
# $$G = \left\langle \left(\begin{array}{rr}
# 1 & -1 \\
# -1 & 2
# \end{array}\right), \left(\begin{array}{rr}
# 3 & 2 \\
# 2 & 1
# \end{array}\right) \right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. _Чи є група G скінченною?_
# 2. _Чи є група G абелевою?_
# 3. _Які порядки мають елементи групи $G$?_
# 4. _Який вигляд мають елементи групи $G$?_
# 6. _Чи є група $G$ циклічною? Якщо так, то знайдіть її твірний елемент._
#
#
# __Ваші відповіді__:
# 1. ...
# 2. ...
# 3. ...
# 4. ...
# 5. ...

# %%
# Ваш код тут:
